# %% [markdown]
# # Automate the retrieval of PDF records for companies
#
# Can get basic company information using;  GET https://api.companieshouse.gov.uk/company/{company_number}
#
# Can get their filing history with;  GET https://api.companieshouse.gov.uk/company/{company_number}/filing-history
#
# Can retrieve a specific document with;  GET http://document-api.companieshouse.gov.uk/document/{id}/content

# %%
import requests
import json
import shutil
import pymongo
import time as tic

import numpy as np
import pandas as pd

# %% [markdown]
# ## Putting together the code for querying the Companies House API

# %%
information_url = "https://api.companieshouse.gov.uk/company/{}/filing-history"    # format with CH number
document_url = "GET http://document-api.companieshouse.gov.uk/document/{}" # format with doc id

# %%
with open("CH_api_key.txt") as f:
    key = f.read().split(":")[-1].strip()

# %%
r = requests.get(information_url.format("00002404"), auth=(key, ""))

# %%
r.json()
# Out:
# {'items': [{'action_date': '2018-11-15',
#    'subcategory': 'termination',
#    'links': {'self': '/company/00002404/filing-history/MzIxOTQ5MTk4M2FkaXF6a2N4',
#     'document_metadata': 'https://frontend-doc-api.companieshouse.gov.uk/document/vmITVZ_ZjKC-iKDcxqKsBtvmIbjwck98jLFrLC-z3as'},
#    'description': 'termination-director-company-with-name-termination-date',
#    'category': 'officers',
#    'type': 'TM01',
#    'date': '2018-11-15',
#    'description_values': {'officer_name': 'Jonathan Mark Moorhouse Green',
#     'termination_date': '2018-11-15'},
#    'pages': 1,
#    'barcode': 'X7IROPXM',
#    'transaction_id': 'MzIxOTQ5MTk4M2FkaXF6a2N4'},
#   {'links': {'self': '/company/00002404/filing-history/MzIxOTQ5MTk3NWFkaXF6a2N4',
#     'document_metadata': 'https://frontend-doc-api.companieshouse.gov.uk/document/gPFzKFmG1b4yblMB-HXAbS_ep98CTKEW5rTCpY3wuLA'},
#    'description': 'termination-director-company-with-name-termination-date',
#    'subcategory': 'termination',
#    'action_date': '2018-11-15',
#    'description_values': {'officer_name': 'Arthur Murray Carter',
#     'termination_date': '2018-11-15'},
#    'date': '2018-11-15',
#    'category': 'officers',
#    'type': 'TM01',
#    'pages': 1,
#    'barcode': 'X7IROPK8',
#    'transaction_id': 'MzIxOTQ5MTk3NWFkaXF6a2N4'},
#   {'category': 'officers',
#    'type': 'AP01',
#    'date': '2018-10-30',
#    'description_values': {'appointment_date': '2018-10-30',
#     'officer_name': 'Mrs Deborah Louise Reed'},
#    'action_date': '2018-10-30',
#    'subcategory': 'appointments',
#    'description': 'appoint-person-director-company-with-name-date',
#    'links': {'self': '/company/00002404/filing-history/MzIxODIyNzk5MWFkaXF6a2N4',
#     'document_metadata': 'https://frontend-doc-api.companieshouse.gov.uk/document/R5DHcqzKAVsKzUchgnPJWLbsRIT9RWhuoXMOF2LCPvU'},
#    'pages': 2,
#    'barcode': 'X7HNGTPA',
#    'transaction_id': 'MzIxODIyNzk5MWFkaXF6a2N4'},
#   {'subcategory': 'termination',
#    'links': {'self': '/company/00002404/filing-history/MzIxODIyNzk5N2FkaXF6a2N4',
#     'document_metadata': 'https://frontend-doc-api.companieshouse.gov.uk/document/c5elPFjD9dFYX5OiDJ7fjegJ94F13Tggs-j3iu_gIKY'},
#    'description': 'termination-director-company-with-name-termination-date',
#    'action_date': '2018-10-30',
#    'description_values': {'officer_name': 'John Wallace Inch',
#     'termination_date': '2018-10-30'},
#    'category': 'officers',
#    'type': 'TM01',
#    'date': '2018-10-30',
#    'pages': 1,
#    'barcode': 'X7HNGU97',
#    'transaction_id': 'MzIxODIyNzk5N2FkaXF6a2N4'},
#   {'type': 'AA',
#    'links': {'self': '/company/00002404/filing-history/MzIxNDg1NDE5MmFkaXF6a2N4',
#     'document_metadata': 'https://frontend-doc-api.companieshouse.gov.uk/document/SKk8jBdX8ZW9-UK1BxJB-He9xB6s6pbMRYW6gZulG5s'},
#    'category': 'accounts',
#    'paper_filed': True,
#    'description': 'accounts-with-accounts-type-full',
#    'action_date': '2017-12-31',
#    'description_values': {'made_up_date': '2017-12-31'},
#    'date': '2018-09-19',
#    'pages': 40,
#    'barcode': 'L7EPMDE3',
#    'transaction_id': 'MzIxNDg1NDE5MmFkaXF6a2N4'},
#   {'date': '2018-08-07',
#    'links': {'self': '/company/00002404/filing-history/MzIxMTU0NzExMGFkaXF6a2N4',
#     'document_metadata': 'https://frontend-doc-api.companieshouse.gov.uk/document/42RdMdb5vl22b1ldaho_UTcc2batnf7AyUOy8dGMujA'},
#    'description': 'confirmation-statement-with-updates',
#    'description_values': {'made_up_date': '2018-08-07'},
#    'action_date': '2018-08-07',
#    'category': 'confirmation-statement',
#    'type': 'CS01',
#    'pages': 5,
#    'barcode': 'X7BTFLWO',
#    'transaction_id': 'MzIxMTU0NzExMGFkaXF6a2N4'},
#   {'links': {'self': '/company/00002404/filing-history/MzIwOTkwODgxNGFkaXF6a2N4',
#     'document_metadata': 'https://frontend-doc-api.companieshouse.gov.uk/document/Kxvbfx7sMtFi5N0CxRj96R-QHqd1VUKbtCxDrOCbEa0'},
#    'category': 'mortgage',
#    'type': 'MR01',
#    'date': '2018-07-17',
#    'action_date': '2018-07-13',
#    'subcategory': 'create',
#    'description_values': {'charge_number': '000024040115',
#     'charge_creation_date': '2018-07-13'},
#    'description': 'mortgage-create-with-deed-with-charge-number-charge-creation-date',
#    'pages': 32,
#    'barcode': 'X7AE532W',
#    'transaction_id': 'MzIwOTkwODgxNGFkaXF6a2N4'},
#   {'description_values': {'officer_name': 'Frances Charlotte Collins',
#     'appointment_date': '2018-06-21'},
#    'subcategory': 'appointments',
#    'action_date': '2018-06-21',
#    'description': 'appoint-person-director-company-with-name-date',
#    'category': 'officers',
#    'type': 'AP01',
#    'links': {'self': '/company/00002404/filing-history/MzIwODI4NjkxMmFkaXF6a2N4',
#     'document_metadata': 'https://frontend-doc-api.companieshouse.gov.uk/document/i9nyq1OWmwldqG-diaSf_7euMWYnuwlkrhNEMMrdlmM'},
#    'date': '2018-06-26',
#    'pages': 2,
#    'barcode': 'X78XJURU',
#    'transaction_id': 'MzIwODI4NjkxMmFkaXF6a2N4'},
#   {'category': 'mortgage',
#    'date': '2018-02-05',
#    'subcategory': 'create',
#    'description_values': {'charge_number': '000024040112',
#     'charge_creation_date': '2018-01-31'},
#    'type': 'MR01',
#    'description': 'mortgage-create-with-deed-with-charge-number-charge-creation-date',
#    'links': {'self': '/company/00002404/filing-history/MzE5NzAwMDAzM2FkaXF6a2N4',
#     'document_metadata': 'https://frontend-doc-api.companieshouse.gov.uk/document/Ta9qoNmS5049Jb11W2bx4Yk0VP4WhkhWKlGjtOThbVQ'},
#    'action_date': '2018-01-31',
#    'pages': 13,
#    'barcode': 'X6Z506XL',
#    'transaction_id': 'MzE5NzAwMDAzM2FkaXF6a2N4'},
#   {'type': 'MR01',
#    'description_values': {'charge_creation_date': '2018-01-31',
#     'charge_number': '000024040113'},
#    'description': 'mortgage-create-with-deed-with-charge-number-charge-creation-date',
#    'links': {'self': '/company/00002404/filing-history/MzE5NzAwNTI1NmFkaXF6a2N4',
#     'document_metadata': 'https://frontend-doc-api.companieshouse.gov.uk/document/T6IF2n42lPQrS8kIqP22eaovf8cJzhxTCS39BbscLkk'},
#    'action_date': '2018-01-31',
#    'category': 'mortgage',
#    'date': '2018-02-05',
#    'subcategory': 'create',
#    'pages': 40,
#    'barcode': 'X6Z56OGB',
#    'transaction_id': 'MzE5NzAwNTI1NmFkaXF6a2N4'},
#   {'date': '2018-02-05',
#    'subcategory': 'create',
#    'category': 'mortgage',
#    'action_date': '2018-01-31',
#    'links': {'self': '/company/00002404/filing-history/MzE5NzAwNjI5OWFkaXF6a2N4',
#     'document_metadata': 'https://frontend-doc-api.companieshouse.gov.uk/document/uvno5IhmCubG8A6H3RjKpJTebodglaNlt6t0AY5qfxM'},
#    'description_values': {'charge_number': '000024040114',
#     'charge_creation_date': '2018-01-31'},
#    'type': 'MR01',
#    'description': 'mortgage-create-with-deed-with-charge-number-charge-creation-date',
#    'pages': 9,
#    'barcode': 'X6Z582KQ',
#    'transaction_id': 'MzE5NzAwNjI5OWFkaXF6a2N4'},
#   {'date': '2018-02-01',
#    'subcategory': 'notifications',
#    'links': {'self': '/company/00002404/filing-history/MzE5Njc2MTg2NGFkaXF6a2N4',
#     'document_metadata': 'https://frontend-doc-api.companieshouse.gov.uk/document/6Zyb-KdxJj78e7aFFzb-nTcmBUdIWHzk6Sbg_NpJgzU'},
#    'category': 'persons-with-significant-control',
#    'type': 'PSC02',
#    'description': 'notification-of-a-person-with-significant-control',
#    'action_date': '2018-01-31',
#    'description_values': {'psc_name': 'Falcon Acquisitions Limited',
#     'notification_date': '2018-01-31'},
#    'pages': 2,
#    'barcode': 'X6YVREYI',
#    'transaction_id': 'MzE5Njc2MTg2NGFkaXF6a2N4'},
#   {'type': 'PSC07',
#    'description': 'cessation-of-a-person-with-significant-control',
#    'description_values': {'psc_name': 'Red Funnel Group (Holdings) Limited',
#     'cessation_date': '2018-01-31'},
#    'action_date': '2018-01-31',
#    'date': '2018-02-01',
#    'links': {'self': '/company/00002404/filing-history/MzE5Njc2MTY0NmFkaXF6a2N4',
#     'document_metadata': 'https://frontend-doc-api.companieshouse.gov.uk/document/dwPBdWsajfvidqBGCwLgU0IKjAtRZ10AJVipg0uEwlY'},
#    'subcategory': 'termination',
#    'category': 'persons-with-significant-control',
#    'pages': 1,
#    'barcode': 'X6YVR76H',
#    'transaction_id': 'MzE5Njc2MTY0NmFkaXF6a2N4'},
#   {'description': 'notification-of-a-person-with-significant-control',
#    'type': 'PSC02',
#    'action_date': '2018-01-31',
#    'description_values': {'notification_date': '2018-01-31',
#     'psc_name': 'Red Funnel Group (Holdings) Limited'},
#    'date': '2018-02-01',
#    'category': 'persons-with-significant-control',
#    'subcategory': 'notifications',
#    'links': {'self': '/company/00002404/filing-history/MzE5Njc1NDYyOGFkaXF6a2N4',
#     'document_metadata': 'https://frontend-doc-api.companieshouse.gov.uk/document/5idFJQolylYDF_gL8g2aLtionnCwNlFs-7uXQMvj_yA'},
#    'pages': 2,
#    'barcode': 'X6YVJOOP',
#    'transaction_id': 'MzE5Njc1NDYyOGFkaXF6a2N4'},
#   {'action_date': '2018-01-31',
#    'description_values': {'psc_name': 'Red Funnel Group Limited',
#     'cessation_date': '2018-01-31'},
#    'type': 'PSC07',
#    'description': 'cessation-of-a-person-with-significant-control',
#    'links': {'self': '/company/00002404/filing-history/MzE5Njc1NDU2NGFkaXF6a2N4',
#     'document_metadata': 'https://frontend-doc-api.companieshouse.gov.uk/document/oUFpAuI2DeEgtaQH7Ssi_gjDOOSpWrBhzT30W0YTIw4'},
#    'subcategory': 'termination',
#    'category': 'persons-with-significant-control',
#    'date': '2018-02-01',
#    'pages': 1,
#    'barcode': 'X6YVJML7',
#    'transaction_id': 'MzE5Njc1NDU2NGFkaXF6a2N4'},
#   {'type': 'PSC02',
#    'description': 'notification-of-a-person-with-significant-control',
#    'action_date': '2018-01-31',
#    'description_values': {'psc_name': 'Red Funnel Group Limited',
#     'notification_date': '2018-01-31'},
#    'date': '2018-02-01',
#    'subcategory': 'notifications',
#    'links': {'self': '/company/00002404/filing-history/MzE5Njc1MjMzMGFkaXF6a2N4',
#     'document_metadata': 'https://frontend-doc-api.companieshouse.gov.uk/document/GyHKwVPXj-zZpD49BQq8Vv8zYbatXFseU7fVudm1L6g'},
#    'category': 'persons-with-significant-control',
#    'pages': 2,
#    'barcode': 'X6YVHAY1',
#    'transaction_id': 'MzE5Njc1MjMzMGFkaXF6a2N4'},
#   {'action_date': '2018-01-31',
#    'description_values': {'psc_name': 'Red Funnel Ferries Limited',
#     'cessation_date': '2018-01-31'},
#    'description': 'cessation-of-a-person-with-significant-control',
#    'type': 'PSC07',
#    'category': 'persons-with-significant-control',
#    'links': {'self': '/company/00002404/filing-history/MzE5Njc1MTk2MWFkaXF6a2N4',
#     'document_metadata': 'https://frontend-doc-api.companieshouse.gov.uk/document/DvqMCHr97knvJ9_wBqLviSAzIkra4aGpGL7eEQvC3tA'},
#    'subcategory': 'termination',
#    'date': '2018-02-01',
#    'pages': 1,
#    'barcode': 'X6YVGUEH',
#    'transaction_id': 'MzE5Njc1MTk2MWFkaXF6a2N4'},
#   {'links': {'self': '/company/00002404/filing-history/MzE5Njc3OTk1NGFkaXF6a2N4',
#     'document_metadata': 'https://frontend-doc-api.companieshouse.gov.uk/document/EBMsuk01z3eUSfmii-qMWvyuKb39Q2uvFKD8xbIsSeg'},
#    'description': 'mortgage-charge-part-both-with-charge-number',
#    'description_values': {'charge_number': '000024040111'},
#    'type': 'MR05',
#    'category': 'mortgage',
#    'date': '2018-02-01',
#    'subcategory': 'release-cease',
#    'pages': 2,
#    'barcode': 'X6YTVBSO',
#    'transaction_id': 'MzE5Njc3OTk1NGFkaXF6a2N4'},
#   {'description_values': {'officer_name': 'Shirley Ann Anderson',
#     'termination_date': '2017-12-15'},
#    'links': {'self': '/company/00002404/filing-history/MzE5NDM4OTkzOWFkaXF6a2N4',
#     'document_metadata': 'https://frontend-doc-api.companieshouse.gov.uk/document/vYqWYHIKKi6csiz5IsIgc5VhZp8fDbBAK4F93nbSVa0'},
#    'type': 'TM01',
#    'date': '2018-01-03',
#    'description': 'termination-director-company-with-name-termination-date',
#    'action_date': '2017-12-15',
#    'category': 'officers',
#    'subcategory': 'termination',
#    'pages': 1,
#    'barcode': 'X6WVFCMZ',
#    'transaction_id': 'MzE5NDM4OTkzOWFkaXF6a2N4'},
#   {'description_values': {'charge_number': '83'},
#    'category': 'mortgage',
#    'links': {'self': '/company/00002404/filing-history/MzE4NjE0Njk5MmFkaXF6a2N4',
#     'document_metadata': 'https://frontend-doc-api.companieshouse.gov.uk/document/jS33QvbiZQwS-gKc4pNd_stnxhOaI5lHAPx5_ksu7C4'},
#    'date': '2017-09-25',
#    'type': 'MR04',
#    'description': 'mortgage-satisfy-charge-full',
#    'subcategory': 'satisfy',
#    'pages': 1,
#    'barcode': 'X6FPZA2X',
#    'transaction_id': 'MzE4NjE0Njk5MmFkaXF6a2N4'},
#   {'subcategory': 'satisfy',
#    'description': 'mortgage-satisfy-charge-full',
#    'type': 'MR04',
#    'date': '2017-09-25',
#    'links': {'self': '/company/00002404/filing-history/MzE4NjE0NzA3NmFkaXF6a2N4',
#     'document_metadata': 'https://frontend-doc-api.companieshouse.gov.uk/document/rXmhVSR7hVIiB7DDpLJMWuRtrm5SHo4-7U4OdxCUzGE'},
#    'category': 'mortgage',
#    'description_values': {'charge_number': '84'},
#    'pages': 1,
#    'barcode': 'X6FPZE15',
#    'transaction_id': 'MzE4NjE0NzA3NmFkaXF6a2N4'},
#   {'category': 'accounts',
#    'description': 'accounts-with-accounts-type-full',
#    'links': {'self': '/company/00002404/filing-history/MzE4NTQzOTM0M2FkaXF6a2N4',
#     'document_metadata': 'https://frontend-doc-api.companieshouse.gov.uk/document/5akrmOTdSkP3Vm6KC8Nv4n6oG-B0ij4QAl5E-eTyafM'},
#    'date': '2017-09-15',
#    'paper_filed': True,
#    'type': 'AA',
#    'description_values': {'made_up_date': '2016-12-31'},
#    'action_date': '2016-12-31',
#    'pages': 41,
#    'barcode': 'A6EL4SIA',
#    'transaction_id': 'MzE4NTQzOTM0M2FkaXF6a2N4'},
#   {'links': {'self': '/company/00002404/filing-history/MzE4MjY5NDYxNGFkaXF6a2N4',
#     'document_metadata': 'https://frontend-doc-api.companieshouse.gov.uk/document/GktITlmghcFk9byJwIV6uz_4Ml1svOGBLPE4ZLzDFC8'},
#    'type': 'MR04',
#    'subcategory': 'satisfy',
#    'description': 'mortgage-satisfy-charge-full',
#    'date': '2017-08-10',
#    'description_values': {'charge_number': '000024040098'},
#    'category': 'mortgage',
#    'pages': 1,
#    'barcode': 'X6CJEAM3',
#    'transaction_id': 'MzE4MjY5NDYxNGFkaXF6a2N4'},
#   {'category': 'mortgage',
#    'description_values': {'charge_number': '000024040097'},
#    'date': '2017-08-10',
#    'description': 'mortgage-satisfy-charge-full',
#    'subcategory': 'satisfy',
#    'type': 'MR04',
#    'links': {'self': '/company/00002404/filing-history/MzE4MjY5NDcwOGFkaXF6a2N4',
#     'document_metadata': 'https://frontend-doc-api.companieshouse.gov.uk/document/7nRz-i8d83HzMlgNn7zZ1cuw5rUKDTS7X2gO5HpMJSU'},
#    'pages': 1,
#    'barcode': 'X6CJEBJF',
#    'transaction_id': 'MzE4MjY5NDcwOGFkaXF6a2N4'},
#   {'links': {'self': '/company/00002404/filing-history/MzE4MjY5NDYyM2FkaXF6a2N4',
#     'document_metadata': 'https://frontend-doc-api.companieshouse.gov.uk/document/dfEQPgbLmTKTa1VRC-I7GqXNB7h5ScvmeAgx0zi2New'},
#    'subcategory': 'satisfy',
#    'type': 'MR04',
#    'date': '2017-08-10',
#    'description': 'mortgage-satisfy-charge-full',
#    'description_values': {'charge_number': '000024040099'},
#    'category': 'mortgage',
#    'pages': 1,
#    'barcode': 'X6CJEB60',
#    'transaction_id': 'MzE4MjY5NDYyM2FkaXF6a2N4'}],
#  'filing_history_status': 'filing-history-available',
#  'start_index': 0,
#  'items_per_page': 25,
#  'total_count': 397}

# %%
# This finds all transaction id's for annual account documents

doc_ids = []

for each in r.json()['items']:
    
    if each['type'] == "AA":
        doc_ids.append( each['links']['document_metadata'])

doc_ids
# Out:
# ['https://frontend-doc-api.companieshouse.gov.uk/document/SKk8jBdX8ZW9-UK1BxJB-He9xB6s6pbMRYW6gZulG5s',
#  'https://frontend-doc-api.companieshouse.gov.uk/document/5akrmOTdSkP3Vm6KC8Nv4n6oG-B0ij4QAl5E-eTyafM']

# %%
aa = requests.get(doc_ids[0] + "/content", auth=(key, ""))

# %%
with open("test.pdf", "wb") as f:
        f.write(aa.content)

# %% [markdown]
# ## Create a list of companies for which we don't have an electronic record on file

# %%
# Connect to mongodb of digital records for purposes of cross-checking
# Believe I've previously generated an index on CH code so searching should be fast
import pymongo

cl = pymongo.MongoClient()
db = cl['CH_records']
col = db['digital_record_scrapes']

# %%
test = col.find_one()

# %%
test
# Out:
# {'_id': ObjectId('5bd87f507db16a3f89d15dfc'),
#  'doc_name': 'Prod224_0052_08028272_20170630.html',
#  'doc_type': 'html',
#  'doc_upload_date': '2018-10-30 15:57:03.613731',
#  'arc_name': 'Accounts_Monthly_Data-March2018',
#  'parsed': True,
#  'doc_balancesheetdate': '2017-06-30',
#  'doc_companieshouseregisterednumber': '08028272',
#  'doc_standard_type': 'FRS-102',
#  'doc_standard_date': '2014-09-01',
#  'doc_standard_link': 'https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS-102-2014-09-01.xsd',
#  'elements': [{'name': 'entitycurrentlegalorregisteredname',
#    'value': 'Cromore Ltd',
#    'unit': 'NA',
#    'date': '2017-06-30'},
#   {'name': 'ukcompanieshouseregisterednumber',
#    'value': '08028272',
#    'unit': 'NA',
#    'date': '2017-06-30'},
#   {'name': 'entitydormanttruefalse',
#    'value': 'false',
#    'unit': 'NA',
#    'date': '2017-06-30'},
#   {'name': 'entitytradingstatus',
#    'value': '',
#    'unit': 'NA',
#    'date': '2017-06-30'},
#   {'name': 'startdateforperiodcoveredbyreport',
#    'value': '2016-07-01',
#    'unit': 'NA',
#    'date': '2017-06-30'},
#   {'name': 'enddateforperiodcoveredbyreport',
#    'value': '2017-06-30',
#    'unit': 'NA',
#    'date': '2017-06-30'},
#   {'name': 'balancesheetdate',
#    'value': '2017-06-30',
#    'unit': 'NA',
#    'date': '2017-06-30'},
#   {'name': 'accountingstandardsapplied',
#    'value': 'Micro-entities',
#    'unit': 'NA',
#    'date': '2017-06-30'},
#   {'name': 'accountsstatusauditedorunaudited',
#    'value': 'AuditExemptWithAccountantsReport',
#    'unit': 'NA',
#    'date': '2017-06-30'},
#   {'name': 'accountstypefullorabbreviated',
#    'value': 'FullAccounts',
#    'unit': 'NA',
#    'date': '2017-06-30'},
#   {'name': 'descriptionprincipalactivities',
#    'value': 'The principal activity of the company is Motorsport & Engineering',
#    'unit': 'NA',
#    'date': '2017-06-30'},
#   {'name': 'nameproductionsoftware',
#    'value': 'Digita Accounts Production Advanced 6.20.8420.0',
#    'unit': 'NA',
#    'date': '2017-06-30'},
#   {'name': 'versionproductionsoftware',
#    'value': 'Software',
#    'unit': 'NA',
#    'date': '2017-06-30'},
#   {'name': 'entityhasclaimedexemptionfromreportingdisclosurekeymanagementpersonnelcompensationtruefalse',
#    'value': 'true',
#    'unit': 'NA',
#    'date': '2017-06-30'},
#   {'name': 'countryformationorincorporation',
#    'value': 'England',
#    'unit': 'NA',
#    'date': '2017-06-30'},
#   {'name': 'legalformentity',
#    'value': 'PrivateLimitedCompanyLtd',
#    'unit': 'NA',
#    'date': '2017-06-30'},
#   {'name': 'directorsigningfinancialstatements',
#    'value': 'Director1',
#    'unit': 'NA',
#    'date': '2017-06-30'},
#   {'name': 'ukcompanieshouseregisterednumber',
#    'value': '08028272',
#    'unit': 'NA',
#    'date': '2017-06-30'},
#   {'name': 'reporttitle',
#    'value': 'Annual Report and Unaudited Financial Statements',
#    'unit': 'NA',
#    'date': '2017-06-30'},
#   {'name': 'nameentityaccountants',
#    'value': 'Saul Fairholm Limited',
#    'unit': 'NA',
#    'date': '2017-06-30'},
#   {'name': 'nameentityofficer',
#    'value': 'Mr M Wilcox',
#    'unit': 'NA',
#    'date': '2017-06-30'},
#   {'name': 'nameentityofficer',
#    'value': 'Mrs S Wilcox',
#    'unit': 'NA',
#    'date': '2017-06-30'},
#   {'name': 'nameentityofficer',
#    'value': 'Miss C E Wilcox',
#    'unit': 'NA',
#    'date': '2017-06-30'},
#   {'name': 'addressline1',
#    'value': '12 Tentercroft Street',
#    'unit': 'NA',
#    'date': '2017-06-30'},
#   {'name': 'principallocation-cityortown',
#    'value': 'Lincoln',
#    'unit': 'NA',
#    'date': '2017-06-30'},
#   {'name': 'countyregion',
#    'value': 'Lincolnshire',
#    'unit': 'NA',
#    'date': '2017-06-30'},
#   {'name': 'postalcodezip',
#    'value': 'LN5 7DB',
#    'unit': 'NA',
#    'date': '2017-06-30'},
#   {'name': 'nameentityaccountants',
#    'value': 'Saul Fairholm Limited',
#    'unit': 'NA',
#    'date': '2017-06-30'},
#   {'name': 'fixedassets',
#    'value': 13184.0,
#    'unit': 'GBP',
#    'date': '2017-06-30'},
#   {'name': 'fixedassets',
#    'value': 10208.0,
#    'unit': 'GBP',
#    'date': '2016-06-30'},
#   {'name': 'currentassets',
#    'value': 59532.0,
#    'unit': 'GBP',
#    'date': '2017-06-30'},
#   {'name': 'currentassets',
#    'value': 41264.0,
#    'unit': 'GBP',
#    'date': '2016-06-30'},
#   {'name': 'prepaymentsaccruedincomenotexpressedwithincurrentassetsubtotal',
#    'value': 941.0,
#    'unit': 'GBP',
#    'date': '2017-06-30'},
#   {'name': 'creditors', 'value': 38628.0, 'unit': 'GBP', 'date': '2017-06-30'},
#   {'name': 'creditors', 'value': 30964.0, 'unit': 'GBP', 'date': '2016-06-30'},
#   {'name': 'netcurrentassetsliabilities',
#    'value': 21845.0,
#    'unit': 'GBP',
#    'date': '2017-06-30'},
#   {'name': 'netcurrentassetsliabilities',
#    'value': 10300.0,
#    'unit': 'GBP',
#    'date': '2016-06-30'},
#   {'name': 'totalassetslesscurrentliabilities',
#    'value': 35029.0,
#    'unit': 'GBP',
#    'date': '2017-06-30'},
#   {'name': 'totalassetslesscurrentliabilities',
#    'value': 20508.0,
#    'unit': 'GBP',
#    'date': '2016-06-30'},
#   {'name': 'accruedliabilitiesnotexpressedwithincreditorssubtotal',
#    'value': -1030.0,
#    'unit': 'GBP',
#    'date': '2017-06-30',
#    'sign': '-'},
#   {'name': 'accruedliabilitiesnotexpressedwithincreditorssubtotal',
#    'value': -1030.0,
#    'unit': 'GBP',
#    'date': '2016-06-30',
#    'sign': '-'},
#   {'name': 'netassetsliabilities',
#    'value': 33999.0,
#    'unit': 'GBP',
#    'date': '2017-06-30'},
#   {'name': 'netassetsliabilities',
#    'value': 19478.0,
#    'unit': 'GBP',
#    'date': '2016-06-30'},
#   {'name': 'equity', 'value': 33999.0, 'unit': 'GBP', 'date': '2017-06-30'},
#   {'name': 'equity', 'value': 19478.0, 'unit': 'GBP', 'date': '2016-06-30'},
#   {'name': 'addressline1',
#    'value': '12 Tentercroft Street',
#    'unit': 'NA',
#    'date': '2017-06-30'},
#   {'name': 'principallocation-cityortown',
#    'value': 'Lincoln',
#    'unit': 'NA',
#    'date': '2017-06-30'},
#   {'name': 'countyregion',
#    'value': 'Lincolnshire',
#    'unit': 'NA',
#    'date': '2017-06-30'},
#   {'name': 'postalcodezip',
#    'value': 'LN5 7DB',
#    'unit': 'NA',
#    'date': '2017-06-30'},
#   {'name': 'descriptionbodyauthorisingfinancialstatements',
#    'value': 'Board',
#    'unit': 'NA',
#    'date': '2017-06-30'},
#   {'name': 'datesigningdirectorsreport',
#    'value': '19 March 2018',
#    'unit': 'NA',
#    'date': '2017-06-30'},
#   {'name': 'statementcompliancewithapplicablereportingframework',
#    'value': "The financial statements have been prepared under the historical cost convention and in accordance with FRS 105 'The Financial Reporting Standard applicable to the Micro-entities Regime'.",
#    'unit': 'NA',
#    'date': '2017-06-30'},
#   {'name': 'statementthataccountshavebeenpreparedinaccordancewithprovisionssmallcompaniesregime',
#    'value': 'These financial statements have been prepared in accordance with the micro-entity provisions of the Companies Act 2006 and delivered in accordance with the provisions applicable to companies subject to the small companies regime.',
#    'unit': 'NA',
#    'date': '2017-06-30'},
#   {'name': 'statementthatcompanyentitledtoexemptionfromauditundersection477companiesact2006relatingtosmallcompanies',
#    'value': 'For the financial year ending 30 June 2017 the company was entitled to exemption from audit under section 477 of the Companies Act 2006 relating to small companies.',
#    'unit': 'NA',
#    'date': '2017-06-30'},
#   {'name': 'statementthatmembershavenotrequiredcompanytoobtainanaudit',
#    'value': 'The members have not required the company to obtain an audit of its accounts for the year in question in accordance with section 476',
#    'unit': 'NA',
#    'date': '2017-06-30'},
#   {'name': 'statementthatdirectorsacknowledgetheirresponsibilitiesundercompaniesact',
#    'value': 'The directors acknowledge their responsibilities for complying with the requirements of the Act with respect to accounting records and the preparation of accounts.',
#    'unit': 'NA',
#    'date': '2017-06-30'},
#   {'name': 'descriptionbodyauthorisingfinancialstatements',
#    'value': 'Board',
#    'unit': 'NA',
#    'date': '2017-06-30'},
#   {'name': 'dateauthorisationfinancialstatementsforissue',
#    'value': '19 March 2018',
#    'unit': 'NA',
#    'date': '2017-06-30'}]}

# %%
counter = 0
recorded = 0

# Load the very large CSV in chunks (to fit within RAM)
for chunk in pd.read_csv("~/data/BasicCompanyDataAsOneFile-2018-10-01.csv", chunksize=1000):
    print("Loaded chunk {}, containing {} records".format(counter, len(chunk)))
    
    no_record = pd.DataFrame()
    
    # Iterate through the entries, checking if each exists in the database
    for index, row in chunk.iterrows():
        doc_count = col.count_documents({'doc_companieshouseregisterednumber':row[' CompanyNumber']})
        
        # If it doesn't, record it
        if doc_count == 0:
            no_record = no_record.append(row, ignore_index=True)
            recorded += 1
    
    # Append the discovered missing DB entries to the output csv file
    if (counter > 0) & (len(no_record) > 0):
        with open("./output/CH_no_digital_records.csv", 'a') as f:
            no_record.to_csv(f, mode='a', header=False, index=False)
            print("Saved a chunk")
    
    # Create a csv file for the discovered missing DB entries if one doesn't exist yet
    else:
        no_record.to_csv("./output/CH_no_digital_records.csv", index=False)
        print("Saved first chunk")
    
    counter += 1
# Out:
# Loaded chunk 0, containing 1000 records
# Saved first chunk
# Loaded chunk 1, containing 1000 records
# Saved a chunk
# Loaded chunk 2, containing 1000 records
# Saved a chunk
# Loaded chunk 3, containing 1000 records
# Saved a chunk
# Loaded chunk 4, containing 1000 records
# Saved a chunk
# Loaded chunk 5, containing 1000 records
# Saved a chunk
# Loaded chunk 6, containing 1000 records
# Saved a chunk
# Loaded chunk 7, containing 1000 records
# Saved a chunk
# Loaded chunk 8, containing 1000 records
# Saved a chunk
# Loaded chunk 9, containing 1000 records
# Saved a chunk
# Loaded chunk 10, containing 1000 records
# Saved a chunk
# Loaded chunk 11, containing 1000 records
# Saved a chunk
# Loaded chunk 12, containing 1000 records
# Saved a chunk
# Loaded chunk 13, containing 1000 records
# Saved a chunk
# Loaded chunk 14, containing 1000 records
# Saved a chunk
# Loaded chunk 15, containing 1000 records
# Saved a chunk
# Loaded chunk 16, containing 1000 records
# Saved a chunk
# Loaded chunk 17, containing 1000 records
# Saved a chunk
# Loaded chunk 18, containing 1000 records
# Saved a chunk
# Loaded chunk 19, containing 1000 records
# Saved a chunk
# Loaded chunk 20, containing 1000 records
# Saved a chunk
# Loaded chunk 21, containing 1000 records
# Saved a chunk
# Loaded chunk 22, containing 1000 records
# Saved a chunk
# Loaded chunk 23, containing 1000 records
# Saved a chunk
# Loaded chunk 24, containing 1000 records
# Saved a chunk
# Loaded chunk 25, containing 1000 records
# Saved a chunk
# Loaded chunk 26, containing 1000 records
# Saved a chunk
# Loaded chunk 27, containing 1000 records
# Saved a chunk
# Loaded chunk 28, containing 1000 records
# Saved a chunk
# Loaded chunk 29, containing 1000 records
# Saved a chunk
# Loaded chunk 30, containing 1000 records
# Saved a chunk
# Loaded chunk 31, containing 1000 records
# Saved a chunk
# Loaded chunk 32, containing 1000 records
# Saved a chunk
# Loaded chunk 33, containing 1000 records
# Saved a chunk
# Loaded chunk 34, containing 1000 records
# Saved a chunk
# Loaded chunk 35, containing 1000 records
# Saved a chunk
# Loaded chunk 36, containing 1000 records
# Saved a chunk
# Loaded chunk 37, containing 1000 records
# Saved a chunk
# Loaded chunk 38, containing 1000 records
# Saved a chunk
# Loaded chunk 39, containing 1000 records
# Saved a chunk
# Loaded chunk 40, containing 1000 records
# Saved a chunk
# Loaded chunk 41, containing 1000 records
# Saved a chunk
# Loaded chunk 42, containing 1000 records
# Saved a chunk
# Loaded chunk 43, containing 1000 records
# Saved a chunk
# Loaded chunk 44, containing 1000 records
# Saved a chunk
# Loaded chunk 45, containing 1000 records
# Saved a chunk
# Loaded chunk 46, containing 1000 records
# Saved a chunk
# Loaded chunk 47, containing 1000 records
# Saved a chunk
# Loaded chunk 48, containing 1000 records
# Saved a chunk
# Loaded chunk 49, containing 1000 records
# Saved a chunk
# Loaded chunk 50, containing 1000 records
# Saved a chunk
# Loaded chunk 51, containing 1000 records
# Saved a chunk
# Loaded chunk 52, containing 1000 records
# Saved a chunk
# Loaded chunk 53, containing 1000 records
# Saved a chunk
# Loaded chunk 54, containing 1000 records
# Saved a chunk
# Loaded chunk 55, containing 1000 records
# Saved a chunk
# Loaded chunk 56, containing 1000 records
# Saved a chunk
# Loaded chunk 57, containing 1000 records
# Saved a chunk
# Loaded chunk 58, containing 1000 records
# Saved a chunk
# Loaded chunk 59, containing 1000 records
# Saved a chunk
# Loaded chunk 60, containing 1000 records
# Saved a chunk
# Loaded chunk 61, containing 1000 records
# Saved a chunk
# Loaded chunk 62, containing 1000 records
# Saved a chunk
# Loaded chunk 63, containing 1000 records
# Saved a chunk
# Loaded chunk 64, containing 1000 records
# Saved a chunk
# Loaded chunk 65, containing 1000 records
# Saved a chunk
# Loaded chunk 66, containing 1000 records
# Saved a chunk
# Loaded chunk 67, containing 1000 records
# Saved a chunk
# Loaded chunk 68, containing 1000 records
# Saved a chunk
# Loaded chunk 69, containing 1000 records
# Saved a chunk
# Loaded chunk 70, containing 1000 records
# Saved a chunk
# Loaded chunk 71, containing 1000 records
# Saved a chunk
# Loaded chunk 72, containing 1000 records
# Saved a chunk
# Loaded chunk 73, containing 1000 records
# Saved a chunk
# Loaded chunk 74, containing 1000 records
# Saved a chunk
# Loaded chunk 75, containing 1000 records
# Saved a chunk
# Loaded chunk 76, containing 1000 records
# Saved a chunk
# Loaded chunk 77, containing 1000 records
# Saved a chunk
# Loaded chunk 78, containing 1000 records
# Saved a chunk
# Loaded chunk 79, containing 1000 records
# Saved a chunk
# Loaded chunk 80, containing 1000 records
# Saved a chunk
# Loaded chunk 81, containing 1000 records
# Saved a chunk
# Loaded chunk 82, containing 1000 records
# Saved a chunk
# Loaded chunk 83, containing 1000 records
# Saved a chunk
# Loaded chunk 84, containing 1000 records
# Saved a chunk
# Loaded chunk 85, containing 1000 records
# Saved a chunk
# Loaded chunk 86, containing 1000 records
# Saved a chunk
# Loaded chunk 87, containing 1000 records
# Saved a chunk
# Loaded chunk 88, containing 1000 records
# Saved a chunk
# Loaded chunk 89, containing 1000 records
# Saved a chunk
# Loaded chunk 90, containing 1000 records
# Saved a chunk
# Loaded chunk 91, containing 1000 records
# Saved a chunk
# Loaded chunk 92, containing 1000 records
# Saved a chunk
# Loaded chunk 93, containing 1000 records
# Saved a chunk
# Loaded chunk 94, containing 1000 records
# Saved a chunk
# Loaded chunk 95, containing 1000 records
# Saved a chunk
# Loaded chunk 96, containing 1000 records
# Saved a chunk
# Loaded chunk 97, containing 1000 records
# Saved a chunk
# Loaded chunk 98, containing 1000 records
# Saved a chunk
# Loaded chunk 99, containing 1000 records
# Saved a chunk
# Loaded chunk 100, containing 1000 records
# Saved a chunk
# Loaded chunk 101, containing 1000 records
# Saved a chunk
# Loaded chunk 102, containing 1000 records
# Saved a chunk
# Loaded chunk 103, containing 1000 records
# Saved a chunk
# Loaded chunk 104, containing 1000 records
# Saved a chunk
# Loaded chunk 105, containing 1000 records
# Saved a chunk
# Loaded chunk 106, containing 1000 records
# Saved a chunk
# Loaded chunk 107, containing 1000 records
# Saved a chunk
# Loaded chunk 108, containing 1000 records
# Saved a chunk
# Loaded chunk 109, containing 1000 records
# Saved a chunk
# Loaded chunk 110, containing 1000 records
# Saved a chunk
# Loaded chunk 111, containing 1000 records
# Saved a chunk
# Loaded chunk 112, containing 1000 records
# Saved a chunk
# Loaded chunk 113, containing 1000 records
# Saved a chunk
# Loaded chunk 114, containing 1000 records
# Saved a chunk
# Loaded chunk 115, containing 1000 records
# Saved a chunk
# Loaded chunk 116, containing 1000 records
# Saved a chunk
# Loaded chunk 117, containing 1000 records
# Saved a chunk
# Loaded chunk 118, containing 1000 records
# Saved a chunk
# Loaded chunk 119, containing 1000 records
# Saved a chunk
# Loaded chunk 120, containing 1000 records
# Saved a chunk
# Loaded chunk 121, containing 1000 records
# Saved a chunk
# Loaded chunk 122, containing 1000 records
# Saved a chunk
# Loaded chunk 123, containing 1000 records
# Saved a chunk
# Loaded chunk 124, containing 1000 records
# Saved a chunk
# Loaded chunk 125, containing 1000 records
# Saved a chunk
# Loaded chunk 126, containing 1000 records
# Saved a chunk
# Loaded chunk 127, containing 1000 records
# Saved a chunk
# Loaded chunk 128, containing 1000 records
# Saved a chunk
# Loaded chunk 129, containing 1000 records
# Saved a chunk
# Loaded chunk 130, containing 1000 records
# Saved a chunk
# Loaded chunk 131, containing 1000 records
# Saved a chunk
# Loaded chunk 132, containing 1000 records
# Saved a chunk
# Loaded chunk 133, containing 1000 records
# Saved a chunk
# Loaded chunk 134, containing 1000 records
# Saved a chunk
# Loaded chunk 135, containing 1000 records
# Saved a chunk
# Loaded chunk 136, containing 1000 records
# Saved a chunk
# Loaded chunk 137, containing 1000 records
# Saved a chunk
# Loaded chunk 138, containing 1000 records
# Saved a chunk
# Loaded chunk 139, containing 1000 records
# Saved a chunk
# Loaded chunk 140, containing 1000 records
# Saved a chunk
# Loaded chunk 141, containing 1000 records
# Saved a chunk
# Loaded chunk 142, containing 1000 records
# Saved a chunk
# Loaded chunk 143, containing 1000 records
# Saved a chunk
# Loaded chunk 144, containing 1000 records
# Saved a chunk
# Loaded chunk 145, containing 1000 records
# Saved a chunk
# Loaded chunk 146, containing 1000 records
# Saved a chunk
# Loaded chunk 147, containing 1000 records
# Saved a chunk
# Loaded chunk 148, containing 1000 records
# Saved a chunk
# Loaded chunk 149, containing 1000 records
# Saved a chunk
# Loaded chunk 150, containing 1000 records
# Saved a chunk
# Loaded chunk 151, containing 1000 records
# Saved a chunk
# Loaded chunk 152, containing 1000 records
# Saved a chunk
# Loaded chunk 153, containing 1000 records
# Saved a chunk
# Loaded chunk 154, containing 1000 records
# Saved a chunk
# Loaded chunk 155, containing 1000 records
# Saved a chunk
# Loaded chunk 156, containing 1000 records
# Saved a chunk
# Loaded chunk 157, containing 1000 records
# Saved a chunk
# Loaded chunk 158, containing 1000 records
# Saved a chunk
# Loaded chunk 159, containing 1000 records
# Saved a chunk
# Loaded chunk 160, containing 1000 records
# Saved a chunk
# Loaded chunk 161, containing 1000 records
# Saved a chunk
# Loaded chunk 162, containing 1000 records
# Saved a chunk
# Loaded chunk 163, containing 1000 records
# Saved a chunk
# Loaded chunk 164, containing 1000 records
# Saved a chunk
# Loaded chunk 165, containing 1000 records
# Saved a chunk
# Loaded chunk 166, containing 1000 records
# Saved a chunk
# Loaded chunk 167, containing 1000 records
# Saved a chunk
# Loaded chunk 168, containing 1000 records
# Saved a chunk
# Loaded chunk 169, containing 1000 records
# Saved a chunk
# Loaded chunk 170, containing 1000 records
# Saved a chunk
# Loaded chunk 171, containing 1000 records
# Saved a chunk
# Loaded chunk 172, containing 1000 records
# Saved a chunk
# Loaded chunk 173, containing 1000 records
# Saved a chunk
# Loaded chunk 174, containing 1000 records
# Saved a chunk
# Loaded chunk 175, containing 1000 records
# Saved a chunk
# Loaded chunk 176, containing 1000 records
# Saved a chunk
# Loaded chunk 177, containing 1000 records
# Saved a chunk
# Loaded chunk 178, containing 1000 records
# Saved a chunk
# Loaded chunk 179, containing 1000 records
# Saved a chunk
# Loaded chunk 180, containing 1000 records
# Saved a chunk
# Loaded chunk 181, containing 1000 records
# Saved a chunk
# Loaded chunk 182, containing 1000 records
# Saved a chunk
# Loaded chunk 183, containing 1000 records
# Saved a chunk
# Loaded chunk 184, containing 1000 records
# Saved a chunk
# Loaded chunk 185, containing 1000 records
# Saved a chunk
# Loaded chunk 186, containing 1000 records
# Saved a chunk
# Loaded chunk 187, containing 1000 records
# Saved a chunk
# Loaded chunk 188, containing 1000 records
# Saved a chunk
# Loaded chunk 189, containing 1000 records
# Saved a chunk
# Loaded chunk 190, containing 1000 records
# Saved a chunk
# Loaded chunk 191, containing 1000 records
# Saved a chunk
# Loaded chunk 192, containing 1000 records
# Saved a chunk
# Loaded chunk 193, containing 1000 records
# Saved a chunk
# Loaded chunk 194, containing 1000 records
# Saved a chunk
# Loaded chunk 195, containing 1000 records
# Saved a chunk
# Loaded chunk 196, containing 1000 records
# Saved a chunk
# Loaded chunk 197, containing 1000 records
# Saved a chunk
# Loaded chunk 198, containing 1000 records
# Saved a chunk
# Loaded chunk 199, containing 1000 records
# Saved a chunk
# Loaded chunk 200, containing 1000 records
# Saved a chunk
# Loaded chunk 201, containing 1000 records
# Saved a chunk
# Loaded chunk 202, containing 1000 records
# Saved a chunk
# Loaded chunk 203, containing 1000 records
# Saved a chunk
# Loaded chunk 204, containing 1000 records
# Saved a chunk
# Loaded chunk 205, containing 1000 records
# Saved a chunk
# Loaded chunk 206, containing 1000 records
# Saved a chunk
# Loaded chunk 207, containing 1000 records
# Saved a chunk
# Loaded chunk 208, containing 1000 records
# Saved a chunk
# Loaded chunk 209, containing 1000 records
# Saved a chunk
# Loaded chunk 210, containing 1000 records
# Saved a chunk
# Loaded chunk 211, containing 1000 records
# Saved a chunk
# Loaded chunk 212, containing 1000 records
# Saved a chunk
# Loaded chunk 213, containing 1000 records
# Saved a chunk
# Loaded chunk 214, containing 1000 records
# Saved a chunk
# Loaded chunk 215, containing 1000 records
# Saved a chunk
# Loaded chunk 216, containing 1000 records
# Saved a chunk
# Loaded chunk 217, containing 1000 records
# Saved a chunk
# Loaded chunk 218, containing 1000 records
# Saved a chunk
# Loaded chunk 219, containing 1000 records
# Saved a chunk
# Loaded chunk 220, containing 1000 records
# Saved a chunk
# Loaded chunk 221, containing 1000 records
# Saved a chunk
# Loaded chunk 222, containing 1000 records
# Saved a chunk
# Loaded chunk 223, containing 1000 records
# Saved a chunk
# Loaded chunk 224, containing 1000 records
# Saved a chunk
# Loaded chunk 225, containing 1000 records
# Saved a chunk
# Loaded chunk 226, containing 1000 records
# Saved a chunk
# Loaded chunk 227, containing 1000 records
# Saved a chunk
# Loaded chunk 228, containing 1000 records
# Saved a chunk
# Loaded chunk 229, containing 1000 records
# Saved a chunk
# Loaded chunk 230, containing 1000 records
# Saved a chunk
# Loaded chunk 231, containing 1000 records
# Saved a chunk
# Loaded chunk 232, containing 1000 records
# Saved a chunk
# Loaded chunk 233, containing 1000 records
# Saved a chunk
# Loaded chunk 234, containing 1000 records
# Saved a chunk
# Loaded chunk 235, containing 1000 records
# Saved a chunk
# Loaded chunk 236, containing 1000 records
# Saved a chunk
# Loaded chunk 237, containing 1000 records
# Saved a chunk
# Loaded chunk 238, containing 1000 records
# Saved a chunk
# Loaded chunk 239, containing 1000 records
# Saved a chunk
# Loaded chunk 240, containing 1000 records
# Saved a chunk
# Loaded chunk 241, containing 1000 records
# Saved a chunk
# Loaded chunk 242, containing 1000 records
# Saved a chunk
# Loaded chunk 243, containing 1000 records
# Saved a chunk
# Loaded chunk 244, containing 1000 records
# Saved a chunk
# Loaded chunk 245, containing 1000 records
# Saved a chunk
# Loaded chunk 246, containing 1000 records
# Saved a chunk
# Loaded chunk 247, containing 1000 records
# Saved a chunk
# Loaded chunk 248, containing 1000 records
# Saved a chunk
# Loaded chunk 249, containing 1000 records
# Saved a chunk
# Loaded chunk 250, containing 1000 records
# Saved a chunk
# Loaded chunk 251, containing 1000 records
# Saved a chunk
# Loaded chunk 252, containing 1000 records
# Saved a chunk
# Loaded chunk 253, containing 1000 records
# Saved a chunk
# Loaded chunk 254, containing 1000 records
# Saved a chunk
# Loaded chunk 255, containing 1000 records
# Saved a chunk
# Loaded chunk 256, containing 1000 records
# Saved a chunk
# Loaded chunk 257, containing 1000 records
# Saved a chunk
# Loaded chunk 258, containing 1000 records
# Saved a chunk
# Loaded chunk 259, containing 1000 records
# Saved a chunk
# Loaded chunk 260, containing 1000 records
# Saved a chunk
# Loaded chunk 261, containing 1000 records
# Saved a chunk
# Loaded chunk 262, containing 1000 records
# Saved a chunk
# Loaded chunk 263, containing 1000 records
# Saved a chunk
# Loaded chunk 264, containing 1000 records
# Saved a chunk
# Loaded chunk 265, containing 1000 records
# Saved a chunk
# Loaded chunk 266, containing 1000 records
# Saved a chunk
# Loaded chunk 267, containing 1000 records
# Saved a chunk
# Loaded chunk 268, containing 1000 records
# Saved a chunk
# Loaded chunk 269, containing 1000 records
# Saved a chunk
# Loaded chunk 270, containing 1000 records
# Saved a chunk
# Loaded chunk 271, containing 1000 records
# Saved a chunk
# Loaded chunk 272, containing 1000 records
# Saved a chunk
# Loaded chunk 273, containing 1000 records
# Saved a chunk
# Loaded chunk 274, containing 1000 records
# Saved a chunk
# Loaded chunk 275, containing 1000 records
# Saved a chunk
# Loaded chunk 276, containing 1000 records
# Saved a chunk
# Loaded chunk 277, containing 1000 records
# Saved a chunk
# Loaded chunk 278, containing 1000 records
# Saved a chunk
# Loaded chunk 279, containing 1000 records
# Saved a chunk
# Loaded chunk 280, containing 1000 records
# Saved a chunk
# Loaded chunk 281, containing 1000 records
# Saved a chunk
# Loaded chunk 282, containing 1000 records
# Saved a chunk
# Loaded chunk 283, containing 1000 records
# Saved a chunk
# Loaded chunk 284, containing 1000 records
# Saved a chunk
# Loaded chunk 285, containing 1000 records
# Saved a chunk
# Loaded chunk 286, containing 1000 records
# Saved a chunk
# Loaded chunk 287, containing 1000 records
# Saved a chunk
# Loaded chunk 288, containing 1000 records
# Saved a chunk
# Loaded chunk 289, containing 1000 records
# Saved a chunk
# Loaded chunk 290, containing 1000 records
# Saved a chunk
# Loaded chunk 291, containing 1000 records
# Saved a chunk
# Loaded chunk 292, containing 1000 records
# Saved a chunk
# Loaded chunk 293, containing 1000 records
# Saved a chunk
# Loaded chunk 294, containing 1000 records
# Saved a chunk
# Loaded chunk 295, containing 1000 records
# Saved a chunk
# Loaded chunk 296, containing 1000 records
# Saved a chunk
# Loaded chunk 297, containing 1000 records
# Saved a chunk
# Loaded chunk 298, containing 1000 records
# Saved a chunk
# Loaded chunk 299, containing 1000 records
# Saved a chunk
# Loaded chunk 300, containing 1000 records
# Saved a chunk
# Loaded chunk 301, containing 1000 records
# Saved a chunk
# Loaded chunk 302, containing 1000 records
# Saved a chunk
# Loaded chunk 303, containing 1000 records
# Saved a chunk
# Loaded chunk 304, containing 1000 records
# Saved a chunk
# Loaded chunk 305, containing 1000 records
# Saved a chunk
# Loaded chunk 306, containing 1000 records
# Saved a chunk
# Loaded chunk 307, containing 1000 records
# Saved a chunk
# Loaded chunk 308, containing 1000 records
# Saved a chunk
# Loaded chunk 309, containing 1000 records
# Saved a chunk
# Loaded chunk 310, containing 1000 records
# Saved a chunk
# Loaded chunk 311, containing 1000 records
# Saved a chunk
# Loaded chunk 312, containing 1000 records
# Saved a chunk
# Loaded chunk 313, containing 1000 records
# Saved a chunk
# Loaded chunk 314, containing 1000 records
# Saved a chunk
# Loaded chunk 315, containing 1000 records
# Saved a chunk
# Loaded chunk 316, containing 1000 records
# Saved a chunk
# Loaded chunk 317, containing 1000 records
# Saved a chunk
# Loaded chunk 318, containing 1000 records
# Saved a chunk
# Loaded chunk 319, containing 1000 records
# Saved a chunk
# Loaded chunk 320, containing 1000 records
# Saved a chunk
# Loaded chunk 321, containing 1000 records
# Saved a chunk
# Loaded chunk 322, containing 1000 records
# Saved a chunk
# Loaded chunk 323, containing 1000 records
# Saved a chunk
# Loaded chunk 324, containing 1000 records
# Saved a chunk
# Loaded chunk 325, containing 1000 records
# Saved a chunk
# Loaded chunk 326, containing 1000 records
# Saved a chunk
# Loaded chunk 327, containing 1000 records
# Saved a chunk
# Loaded chunk 328, containing 1000 records
# Saved a chunk
# Loaded chunk 329, containing 1000 records
# Saved a chunk
# Loaded chunk 330, containing 1000 records
# Saved a chunk
# Loaded chunk 331, containing 1000 records
# Saved a chunk
# Loaded chunk 332, containing 1000 records
# Saved a chunk
# Loaded chunk 333, containing 1000 records
# Saved a chunk
# Loaded chunk 334, containing 1000 records
# Saved a chunk
# Loaded chunk 335, containing 1000 records
# Saved a chunk
# Loaded chunk 336, containing 1000 records
# Saved a chunk
# Loaded chunk 337, containing 1000 records
# Saved a chunk
# Loaded chunk 338, containing 1000 records
# Saved a chunk
# Loaded chunk 339, containing 1000 records
# Saved a chunk
# Loaded chunk 340, containing 1000 records
# Saved a chunk
# Loaded chunk 341, containing 1000 records
# Saved a chunk
# Loaded chunk 342, containing 1000 records
# Saved a chunk
# Loaded chunk 343, containing 1000 records
# Saved a chunk
# Loaded chunk 344, containing 1000 records
# Saved a chunk
# Loaded chunk 345, containing 1000 records
# Saved a chunk
# Loaded chunk 346, containing 1000 records
# Saved a chunk
# Loaded chunk 347, containing 1000 records
# Saved a chunk
# Loaded chunk 348, containing 1000 records
# Saved a chunk
# Loaded chunk 349, containing 1000 records
# Saved a chunk
# Loaded chunk 350, containing 1000 records
# Saved a chunk
# Loaded chunk 351, containing 1000 records
# Saved a chunk
# Loaded chunk 352, containing 1000 records
# Saved a chunk
# Loaded chunk 353, containing 1000 records
# Saved a chunk
# Loaded chunk 354, containing 1000 records
# Saved a chunk
# Loaded chunk 355, containing 1000 records
# Saved a chunk
# Loaded chunk 356, containing 1000 records
# Saved a chunk
# Loaded chunk 357, containing 1000 records
# Saved a chunk
# Loaded chunk 358, containing 1000 records
# Saved a chunk
# Loaded chunk 359, containing 1000 records
# Saved a chunk
# Loaded chunk 360, containing 1000 records
# Saved a chunk
# Loaded chunk 361, containing 1000 records
# Saved a chunk
# Loaded chunk 362, containing 1000 records
# Saved a chunk
# Loaded chunk 363, containing 1000 records
# Saved a chunk
# Loaded chunk 364, containing 1000 records
# Saved a chunk
# Loaded chunk 365, containing 1000 records
# Saved a chunk
# Loaded chunk 366, containing 1000 records
# Saved a chunk
# Loaded chunk 367, containing 1000 records
# Saved a chunk
# Loaded chunk 368, containing 1000 records
# Saved a chunk
# Loaded chunk 369, containing 1000 records
# Saved a chunk
# Loaded chunk 370, containing 1000 records
# Saved a chunk
# Loaded chunk 371, containing 1000 records
# Saved a chunk
# Loaded chunk 372, containing 1000 records
# Saved a chunk
# Loaded chunk 373, containing 1000 records
# Saved a chunk
# Loaded chunk 374, containing 1000 records
# Saved a chunk
# Loaded chunk 375, containing 1000 records
# Saved a chunk
# Loaded chunk 376, containing 1000 records
# Saved a chunk
# Loaded chunk 377, containing 1000 records
# Saved a chunk
# Loaded chunk 378, containing 1000 records
# Saved a chunk
# Loaded chunk 379, containing 1000 records
# Saved a chunk
# Loaded chunk 380, containing 1000 records
# Saved a chunk
# Loaded chunk 381, containing 1000 records
# Saved a chunk
# Loaded chunk 382, containing 1000 records
# Saved a chunk
# Loaded chunk 383, containing 1000 records
# Saved a chunk
# Loaded chunk 384, containing 1000 records
# Saved a chunk
# Loaded chunk 385, containing 1000 records
# Saved a chunk
# Loaded chunk 386, containing 1000 records
# Saved a chunk
# Loaded chunk 387, containing 1000 records
# Saved a chunk
# Loaded chunk 388, containing 1000 records
# Saved a chunk
# Loaded chunk 389, containing 1000 records
# Saved a chunk
# Loaded chunk 390, containing 1000 records
# Saved a chunk
# Loaded chunk 391, containing 1000 records
# Saved a chunk
# Loaded chunk 392, containing 1000 records
# Saved a chunk
# Loaded chunk 393, containing 1000 records
# Saved a chunk
# Loaded chunk 394, containing 1000 records
# Saved a chunk
# Loaded chunk 395, containing 1000 records
# Saved a chunk
# Loaded chunk 396, containing 1000 records
# Saved a chunk
# Loaded chunk 397, containing 1000 records
# Saved a chunk
# Loaded chunk 398, containing 1000 records
# Saved a chunk
# Loaded chunk 399, containing 1000 records
# Saved a chunk
# Loaded chunk 400, containing 1000 records
# Saved a chunk
# Loaded chunk 401, containing 1000 records
# Saved a chunk
# Loaded chunk 402, containing 1000 records
# Saved a chunk
# Loaded chunk 403, containing 1000 records
# Saved a chunk
# Loaded chunk 404, containing 1000 records
# Saved a chunk
# Loaded chunk 405, containing 1000 records
# Saved a chunk
# Loaded chunk 406, containing 1000 records
# Saved a chunk
# Loaded chunk 407, containing 1000 records
# Saved a chunk
# Loaded chunk 408, containing 1000 records
# Saved a chunk
# Loaded chunk 409, containing 1000 records
# Saved a chunk
# Loaded chunk 410, containing 1000 records
# Saved a chunk
# Loaded chunk 411, containing 1000 records
# Saved a chunk
# Loaded chunk 412, containing 1000 records
# Saved a chunk
# Loaded chunk 413, containing 1000 records
# Saved a chunk
# Loaded chunk 414, containing 1000 records
# Saved a chunk
# Loaded chunk 415, containing 1000 records
# Saved a chunk
# Loaded chunk 416, containing 1000 records
# Saved a chunk
# Loaded chunk 417, containing 1000 records
# Saved a chunk
# Loaded chunk 418, containing 1000 records
# Saved a chunk
# Loaded chunk 419, containing 1000 records
# Saved a chunk
# Loaded chunk 420, containing 1000 records
# Saved a chunk
# Loaded chunk 421, containing 1000 records
# Saved a chunk
# Loaded chunk 422, containing 1000 records
# Saved a chunk
# Loaded chunk 423, containing 1000 records
# Saved a chunk
# Loaded chunk 424, containing 1000 records
# Saved a chunk
# Loaded chunk 425, containing 1000 records
# Saved a chunk
# Loaded chunk 426, containing 1000 records
# Saved a chunk
# Loaded chunk 427, containing 1000 records
# Saved a chunk
# Loaded chunk 428, containing 1000 records
# Saved a chunk
# Loaded chunk 429, containing 1000 records
# Saved a chunk
# Loaded chunk 430, containing 1000 records
# Saved a chunk
# Loaded chunk 431, containing 1000 records
# Saved a chunk
# Loaded chunk 432, containing 1000 records
# Saved a chunk
# Loaded chunk 433, containing 1000 records
# Saved a chunk
# Loaded chunk 434, containing 1000 records
# Saved a chunk
# Loaded chunk 435, containing 1000 records
# Saved a chunk
# Loaded chunk 436, containing 1000 records
# Saved a chunk
# Loaded chunk 437, containing 1000 records
# Saved a chunk
# Loaded chunk 438, containing 1000 records
# Saved a chunk
# Loaded chunk 439, containing 1000 records
# Saved a chunk
# Loaded chunk 440, containing 1000 records
# Saved a chunk
# Loaded chunk 441, containing 1000 records
# Saved a chunk
# Loaded chunk 442, containing 1000 records
# Saved a chunk
# Loaded chunk 443, containing 1000 records
# Saved a chunk
# Loaded chunk 444, containing 1000 records
# Saved a chunk
# Loaded chunk 445, containing 1000 records
# Saved a chunk
# Loaded chunk 446, containing 1000 records
# Saved a chunk
# Loaded chunk 447, containing 1000 records
# Saved a chunk
# Loaded chunk 448, containing 1000 records
# Saved a chunk
# Loaded chunk 449, containing 1000 records
# Saved a chunk
# Loaded chunk 450, containing 1000 records
# Saved a chunk
# Loaded chunk 451, containing 1000 records
# Saved a chunk
# Loaded chunk 452, containing 1000 records
# Saved a chunk
# Loaded chunk 453, containing 1000 records
# Saved a chunk
# Loaded chunk 454, containing 1000 records
# Saved a chunk
# Loaded chunk 455, containing 1000 records
# Saved a chunk
# Loaded chunk 456, containing 1000 records
# Saved a chunk
# Loaded chunk 457, containing 1000 records
# Saved a chunk
# Loaded chunk 458, containing 1000 records
# Saved a chunk
# Loaded chunk 459, containing 1000 records
# Saved a chunk
# Loaded chunk 460, containing 1000 records
# Saved a chunk
# Loaded chunk 461, containing 1000 records
# Saved a chunk
# Loaded chunk 462, containing 1000 records
# Saved a chunk
# Loaded chunk 463, containing 1000 records
# Saved a chunk
# Loaded chunk 464, containing 1000 records
# Saved a chunk
# Loaded chunk 465, containing 1000 records
# Saved a chunk
# Loaded chunk 466, containing 1000 records
# Saved a chunk
# Loaded chunk 467, containing 1000 records
# Saved a chunk
# Loaded chunk 468, containing 1000 records
# Saved a chunk
# Loaded chunk 469, containing 1000 records
# Saved a chunk
# Loaded chunk 470, containing 1000 records
# Saved a chunk
# Loaded chunk 471, containing 1000 records
# Saved a chunk
# Loaded chunk 472, containing 1000 records
# Saved a chunk
# Loaded chunk 473, containing 1000 records
# Saved a chunk
# Loaded chunk 474, containing 1000 records
# Saved a chunk
# Loaded chunk 475, containing 1000 records
# Saved a chunk
# Loaded chunk 476, containing 1000 records
# Saved a chunk
# Loaded chunk 477, containing 1000 records
# Saved a chunk
# Loaded chunk 478, containing 1000 records
# Saved a chunk
# Loaded chunk 479, containing 1000 records
# Saved a chunk
# Loaded chunk 480, containing 1000 records
# Saved a chunk
# Loaded chunk 481, containing 1000 records
# Saved a chunk
# Loaded chunk 482, containing 1000 records
# Saved a chunk
# Loaded chunk 483, containing 1000 records
# Saved a chunk
# Loaded chunk 484, containing 1000 records
# Saved a chunk
# Loaded chunk 485, containing 1000 records
# Saved a chunk
# Loaded chunk 486, containing 1000 records
# Saved a chunk
# Loaded chunk 487, containing 1000 records
# Saved a chunk
# Loaded chunk 488, containing 1000 records
# Saved a chunk
# Loaded chunk 489, containing 1000 records
# Saved a chunk
# Loaded chunk 490, containing 1000 records
# Saved a chunk
# Loaded chunk 491, containing 1000 records
# Saved a chunk
# Loaded chunk 492, containing 1000 records
# Saved a chunk
# Loaded chunk 493, containing 1000 records
# Saved a chunk
# Loaded chunk 494, containing 1000 records
# Saved a chunk
# Loaded chunk 495, containing 1000 records
# Saved a chunk
# Loaded chunk 496, containing 1000 records
# Saved a chunk
# Loaded chunk 497, containing 1000 records
# Saved a chunk
# Loaded chunk 498, containing 1000 records
# Saved a chunk
# Loaded chunk 499, containing 1000 records
# Saved a chunk
# Loaded chunk 500, containing 1000 records
# Saved a chunk
# Loaded chunk 501, containing 1000 records
# Saved a chunk
# Loaded chunk 502, containing 1000 records
# Saved a chunk
# Loaded chunk 503, containing 1000 records
# Saved a chunk
# Loaded chunk 504, containing 1000 records
# Saved a chunk
# Loaded chunk 505, containing 1000 records
# Saved a chunk
# Loaded chunk 506, containing 1000 records
# Saved a chunk
# Loaded chunk 507, containing 1000 records
# Saved a chunk
# Loaded chunk 508, containing 1000 records
# Saved a chunk
# Loaded chunk 509, containing 1000 records
# Saved a chunk
# Loaded chunk 510, containing 1000 records
# Saved a chunk
# Loaded chunk 511, containing 1000 records
# Saved a chunk
# Loaded chunk 512, containing 1000 records
# Saved a chunk
# Loaded chunk 513, containing 1000 records
# Saved a chunk
# Loaded chunk 514, containing 1000 records
# Saved a chunk
# Loaded chunk 515, containing 1000 records
# Saved a chunk
# Loaded chunk 516, containing 1000 records
# Saved a chunk
# Loaded chunk 517, containing 1000 records
# Saved a chunk
# Loaded chunk 518, containing 1000 records
# Saved a chunk
# Loaded chunk 519, containing 1000 records
# Saved a chunk
# Loaded chunk 520, containing 1000 records
# Saved a chunk
# Loaded chunk 521, containing 1000 records
# Saved a chunk
# Loaded chunk 522, containing 1000 records
# Saved a chunk
# Loaded chunk 523, containing 1000 records
# Saved a chunk
# Loaded chunk 524, containing 1000 records
# Saved a chunk
# Loaded chunk 525, containing 1000 records
# Saved a chunk
# Loaded chunk 526, containing 1000 records
# Saved a chunk
# Loaded chunk 527, containing 1000 records
# Saved a chunk
# Loaded chunk 528, containing 1000 records
# Saved a chunk
# Loaded chunk 529, containing 1000 records
# Saved a chunk
# Loaded chunk 530, containing 1000 records
# Saved a chunk
# Loaded chunk 531, containing 1000 records
# Saved a chunk
# Loaded chunk 532, containing 1000 records
# Saved a chunk
# Loaded chunk 533, containing 1000 records
# Saved a chunk
# Loaded chunk 534, containing 1000 records
# Saved a chunk
# Loaded chunk 535, containing 1000 records
# Saved a chunk
# Loaded chunk 536, containing 1000 records
# Saved a chunk
# Loaded chunk 537, containing 1000 records
# Saved a chunk
# Loaded chunk 538, containing 1000 records
# Saved a chunk
# Loaded chunk 539, containing 1000 records
# Saved a chunk
# Loaded chunk 540, containing 1000 records
# Saved a chunk
# Loaded chunk 541, containing 1000 records
# Saved a chunk
# Loaded chunk 542, containing 1000 records
# Saved a chunk
# Loaded chunk 543, containing 1000 records
# Saved a chunk
# Loaded chunk 544, containing 1000 records
# Saved a chunk
# Loaded chunk 545, containing 1000 records
# Saved a chunk
# Loaded chunk 546, containing 1000 records
# Saved a chunk
# Loaded chunk 547, containing 1000 records
# Saved a chunk
# Loaded chunk 548, containing 1000 records
# Saved a chunk
# Loaded chunk 549, containing 1000 records
# Saved a chunk
# Loaded chunk 550, containing 1000 records
# Saved a chunk
# Loaded chunk 551, containing 1000 records
# Saved a chunk
# Loaded chunk 552, containing 1000 records
# Saved a chunk
# Loaded chunk 553, containing 1000 records
# Saved a chunk
# Loaded chunk 554, containing 1000 records
# Saved a chunk
# Loaded chunk 555, containing 1000 records
# Saved a chunk
# Loaded chunk 556, containing 1000 records
# Saved a chunk
# Loaded chunk 557, containing 1000 records
# Saved a chunk
# Loaded chunk 558, containing 1000 records
# Saved a chunk
# Loaded chunk 559, containing 1000 records
# Saved a chunk
# Loaded chunk 560, containing 1000 records
# Saved a chunk
# Loaded chunk 561, containing 1000 records
# Saved a chunk
# Loaded chunk 562, containing 1000 records
# Saved a chunk
# Loaded chunk 563, containing 1000 records
# Saved a chunk
# Loaded chunk 564, containing 1000 records
# Saved a chunk
# Loaded chunk 565, containing 1000 records
# Saved a chunk
# Loaded chunk 566, containing 1000 records
# Saved a chunk
# Loaded chunk 567, containing 1000 records
# Saved a chunk
# Loaded chunk 568, containing 1000 records
# Saved a chunk
# Loaded chunk 569, containing 1000 records
# Saved a chunk
# Loaded chunk 570, containing 1000 records
# Saved a chunk
# Loaded chunk 571, containing 1000 records
# Saved a chunk
# Loaded chunk 572, containing 1000 records
# Saved a chunk
# Loaded chunk 573, containing 1000 records
# Saved a chunk
# Loaded chunk 574, containing 1000 records
# Saved a chunk
# Loaded chunk 575, containing 1000 records
# Saved a chunk
# Loaded chunk 576, containing 1000 records
# Saved a chunk
# Loaded chunk 577, containing 1000 records
# Saved a chunk
# Loaded chunk 578, containing 1000 records
# Saved a chunk
# Loaded chunk 579, containing 1000 records
# Saved a chunk
# Loaded chunk 580, containing 1000 records
# Saved a chunk
# Loaded chunk 581, containing 1000 records
# Saved a chunk
# Loaded chunk 582, containing 1000 records
# Saved a chunk
# Loaded chunk 583, containing 1000 records
# Saved a chunk
# Loaded chunk 584, containing 1000 records
# Saved a chunk
# Loaded chunk 585, containing 1000 records
# Saved a chunk
# Loaded chunk 586, containing 1000 records
# Saved a chunk
# Loaded chunk 587, containing 1000 records
# Saved a chunk
# Loaded chunk 588, containing 1000 records
# Saved a chunk
# Loaded chunk 589, containing 1000 records
# Saved a chunk
# Loaded chunk 590, containing 1000 records
# Saved a chunk
# Loaded chunk 591, containing 1000 records
# Saved a chunk
# Loaded chunk 592, containing 1000 records
# Saved a chunk
# Loaded chunk 593, containing 1000 records
# Saved a chunk
# Loaded chunk 594, containing 1000 records
# Saved a chunk
# Loaded chunk 595, containing 1000 records
# Saved a chunk
# Loaded chunk 596, containing 1000 records
# Saved a chunk
# Loaded chunk 597, containing 1000 records
# Saved a chunk
# Loaded chunk 598, containing 1000 records
# Saved a chunk
# Loaded chunk 599, containing 1000 records
# Saved a chunk
# Loaded chunk 600, containing 1000 records
# Saved a chunk
# Loaded chunk 601, containing 1000 records
# Saved a chunk
# Loaded chunk 602, containing 1000 records
# Saved a chunk
# Loaded chunk 603, containing 1000 records
# Saved a chunk
# Loaded chunk 604, containing 1000 records
# Saved a chunk
# Loaded chunk 605, containing 1000 records
# Saved a chunk
# Loaded chunk 606, containing 1000 records
# Saved a chunk
# Loaded chunk 607, containing 1000 records
# Saved a chunk
# Loaded chunk 608, containing 1000 records
# Saved a chunk
# Loaded chunk 609, containing 1000 records
# Saved a chunk
# Loaded chunk 610, containing 1000 records
# Saved a chunk
# Loaded chunk 611, containing 1000 records
# Saved a chunk
# Loaded chunk 612, containing 1000 records
# Saved a chunk
# Loaded chunk 613, containing 1000 records
# Saved a chunk
# Loaded chunk 614, containing 1000 records
# Saved a chunk
# Loaded chunk 615, containing 1000 records
# Saved a chunk
# Loaded chunk 616, containing 1000 records
# Saved a chunk
# Loaded chunk 617, containing 1000 records
# Saved a chunk
# Loaded chunk 618, containing 1000 records
# Saved a chunk
# Loaded chunk 619, containing 1000 records
# Saved a chunk
# Loaded chunk 620, containing 1000 records
# Saved a chunk
# Loaded chunk 621, containing 1000 records
# Saved a chunk
# Loaded chunk 622, containing 1000 records
# Saved a chunk
# Loaded chunk 623, containing 1000 records
# Saved a chunk
# Loaded chunk 624, containing 1000 records
# Saved a chunk
# Loaded chunk 625, containing 1000 records
# Saved a chunk
# Loaded chunk 626, containing 1000 records
# Saved a chunk
# Loaded chunk 627, containing 1000 records
# Saved a chunk
# Loaded chunk 628, containing 1000 records
# Saved a chunk
# Loaded chunk 629, containing 1000 records
# Saved a chunk
# Loaded chunk 630, containing 1000 records
# Saved a chunk
# Loaded chunk 631, containing 1000 records
# Saved a chunk
# Loaded chunk 632, containing 1000 records
# Saved a chunk
# Loaded chunk 633, containing 1000 records
# Saved a chunk
# Loaded chunk 634, containing 1000 records
# Saved a chunk
# Loaded chunk 635, containing 1000 records
# Saved a chunk
# Loaded chunk 636, containing 1000 records
# Saved a chunk
# Loaded chunk 637, containing 1000 records
# Saved a chunk
# Loaded chunk 638, containing 1000 records
# Saved a chunk
# Loaded chunk 639, containing 1000 records
# Saved a chunk
# Loaded chunk 640, containing 1000 records
# Saved a chunk
# Loaded chunk 641, containing 1000 records
# Saved a chunk
# Loaded chunk 642, containing 1000 records
# Saved a chunk
# Loaded chunk 643, containing 1000 records
# Saved a chunk
# Loaded chunk 644, containing 1000 records
# Saved a chunk
# Loaded chunk 645, containing 1000 records
# Saved a chunk
# Loaded chunk 646, containing 1000 records
# Saved a chunk
# Loaded chunk 647, containing 1000 records
# Saved a chunk
# Loaded chunk 648, containing 1000 records
# Saved a chunk
# Loaded chunk 649, containing 1000 records
# Saved a chunk
# Loaded chunk 650, containing 1000 records
# Saved a chunk
# Loaded chunk 651, containing 1000 records
# Saved a chunk
# Loaded chunk 652, containing 1000 records
# Saved a chunk
# Loaded chunk 653, containing 1000 records
# Saved a chunk
# Loaded chunk 654, containing 1000 records
# Saved a chunk
# Loaded chunk 655, containing 1000 records
# Saved a chunk
# Loaded chunk 656, containing 1000 records
# Saved a chunk
# Loaded chunk 657, containing 1000 records
# Saved a chunk
# Loaded chunk 658, containing 1000 records
# Saved a chunk
# Loaded chunk 659, containing 1000 records
# Saved a chunk
# Loaded chunk 660, containing 1000 records
# Saved a chunk
# Loaded chunk 661, containing 1000 records
# Saved a chunk
# Loaded chunk 662, containing 1000 records
# Saved a chunk
# Loaded chunk 663, containing 1000 records
# Saved a chunk
# Loaded chunk 664, containing 1000 records
# Saved a chunk
# Loaded chunk 665, containing 1000 records
# Saved a chunk
# Loaded chunk 666, containing 1000 records
# Saved a chunk
# Loaded chunk 667, containing 1000 records
# Saved a chunk
# Loaded chunk 668, containing 1000 records
# Saved a chunk
# Loaded chunk 669, containing 1000 records
# Saved a chunk
# Loaded chunk 670, containing 1000 records
# Saved a chunk
# Loaded chunk 671, containing 1000 records
# Saved a chunk
# Loaded chunk 672, containing 1000 records
# Saved a chunk
# Loaded chunk 673, containing 1000 records
# Saved a chunk
# Loaded chunk 674, containing 1000 records
# Saved a chunk
# Loaded chunk 675, containing 1000 records
# Saved a chunk
# Loaded chunk 676, containing 1000 records
# Saved a chunk
# Loaded chunk 677, containing 1000 records
# Saved a chunk
# Loaded chunk 678, containing 1000 records
# Saved a chunk
# Loaded chunk 679, containing 1000 records
# Saved a chunk
# Loaded chunk 680, containing 1000 records
# Saved a chunk
# Loaded chunk 681, containing 1000 records
# Saved a chunk
# Loaded chunk 682, containing 1000 records
# Saved a chunk
# Loaded chunk 683, containing 1000 records
# Saved a chunk
# Loaded chunk 684, containing 1000 records
# Saved a chunk
# Loaded chunk 685, containing 1000 records
# Saved a chunk
# Loaded chunk 686, containing 1000 records
# Saved a chunk
# Loaded chunk 687, containing 1000 records
# Saved a chunk
# Loaded chunk 688, containing 1000 records
# Saved a chunk
# Loaded chunk 689, containing 1000 records
# Saved a chunk
# Loaded chunk 690, containing 1000 records
# Saved a chunk
# Loaded chunk 691, containing 1000 records
# Saved a chunk
# Loaded chunk 692, containing 1000 records
# Saved a chunk
# Loaded chunk 693, containing 1000 records
# Saved a chunk
# Loaded chunk 694, containing 1000 records
# Saved a chunk
# Loaded chunk 695, containing 1000 records
# Saved a chunk
# Loaded chunk 696, containing 1000 records
# Saved a chunk
# Loaded chunk 697, containing 1000 records
# Saved a chunk
# Loaded chunk 698, containing 1000 records
# Saved a chunk
# Loaded chunk 699, containing 1000 records
# Saved a chunk
# Loaded chunk 700, containing 1000 records
# Saved a chunk
# Loaded chunk 701, containing 1000 records
# Saved a chunk
# Loaded chunk 702, containing 1000 records
# Saved a chunk
# Loaded chunk 703, containing 1000 records
# Saved a chunk
# Loaded chunk 704, containing 1000 records
# Saved a chunk
# Loaded chunk 705, containing 1000 records
# Saved a chunk
# Loaded chunk 706, containing 1000 records
# Saved a chunk
# Loaded chunk 707, containing 1000 records
# Saved a chunk
# Loaded chunk 708, containing 1000 records
# Saved a chunk
# Loaded chunk 709, containing 1000 records
# Saved a chunk
# Loaded chunk 710, containing 1000 records
# Saved a chunk
# Loaded chunk 711, containing 1000 records
# Saved a chunk
# Loaded chunk 712, containing 1000 records
# Saved a chunk
# Loaded chunk 713, containing 1000 records
# Saved a chunk
# Loaded chunk 714, containing 1000 records
# Saved a chunk
# Loaded chunk 715, containing 1000 records
# Saved a chunk
# Loaded chunk 716, containing 1000 records
# Saved a chunk
# Loaded chunk 717, containing 1000 records
# Saved a chunk
# Loaded chunk 718, containing 1000 records
# Saved a chunk
# Loaded chunk 719, containing 1000 records
# Saved a chunk
# Loaded chunk 720, containing 1000 records
# Saved a chunk
# Loaded chunk 721, containing 1000 records
# Saved a chunk
# Loaded chunk 722, containing 1000 records
# Saved a chunk
# Loaded chunk 723, containing 1000 records
# Saved a chunk
# Loaded chunk 724, containing 1000 records
# Saved a chunk
# Loaded chunk 725, containing 1000 records
# Saved a chunk
# Loaded chunk 726, containing 1000 records
# Saved a chunk
# Loaded chunk 727, containing 1000 records
# Saved a chunk
# Loaded chunk 728, containing 1000 records
# Saved a chunk
# Loaded chunk 729, containing 1000 records
# Saved a chunk
# Loaded chunk 730, containing 1000 records
# Saved a chunk
# Loaded chunk 731, containing 1000 records
# Saved a chunk
# Loaded chunk 732, containing 1000 records
# Saved a chunk
# Loaded chunk 733, containing 1000 records
# Saved a chunk
# Loaded chunk 734, containing 1000 records
# Saved a chunk
# Loaded chunk 735, containing 1000 records
# Saved a chunk
# Loaded chunk 736, containing 1000 records
# Saved a chunk
# Loaded chunk 737, containing 1000 records
# Saved a chunk
# Loaded chunk 738, containing 1000 records
# Saved a chunk
# Loaded chunk 739, containing 1000 records
# Saved a chunk
# Loaded chunk 740, containing 1000 records
# Saved a chunk
# Loaded chunk 741, containing 1000 records
# Saved a chunk
# Loaded chunk 742, containing 1000 records
# Saved a chunk
# Loaded chunk 743, containing 1000 records
# Saved a chunk
# Loaded chunk 744, containing 1000 records
# Saved a chunk
# Loaded chunk 745, containing 1000 records
# Saved a chunk
# Loaded chunk 746, containing 1000 records
# Saved a chunk
# Loaded chunk 747, containing 1000 records
# Saved a chunk
# Loaded chunk 748, containing 1000 records
# Saved a chunk
# Loaded chunk 749, containing 1000 records
# Saved a chunk
# Loaded chunk 750, containing 1000 records
# Saved a chunk
# Loaded chunk 751, containing 1000 records
# Saved a chunk
# Loaded chunk 752, containing 1000 records
# Saved a chunk
# Loaded chunk 753, containing 1000 records
# Saved a chunk
# Loaded chunk 754, containing 1000 records
# Saved a chunk
# Loaded chunk 755, containing 1000 records
# Saved a chunk
# Loaded chunk 756, containing 1000 records
# Saved a chunk
# Loaded chunk 757, containing 1000 records
# Saved a chunk
# Loaded chunk 758, containing 1000 records
# Saved a chunk
# Loaded chunk 759, containing 1000 records
# Saved a chunk
# Loaded chunk 760, containing 1000 records
# Saved a chunk
# Loaded chunk 761, containing 1000 records
# Saved a chunk
# Loaded chunk 762, containing 1000 records
# Saved a chunk
# Loaded chunk 763, containing 1000 records
# Saved a chunk
# Loaded chunk 764, containing 1000 records
# Saved a chunk
# Loaded chunk 765, containing 1000 records
# Saved a chunk
# Loaded chunk 766, containing 1000 records
# Saved a chunk
# Loaded chunk 767, containing 1000 records
# Saved a chunk
# Loaded chunk 768, containing 1000 records
# Saved a chunk
# Loaded chunk 769, containing 1000 records
# Saved a chunk
# Loaded chunk 770, containing 1000 records
# Saved a chunk
# Loaded chunk 771, containing 1000 records
# Saved a chunk
# Loaded chunk 772, containing 1000 records
# Saved a chunk
# Loaded chunk 773, containing 1000 records
# Saved a chunk
# Loaded chunk 774, containing 1000 records
# Saved a chunk
# Loaded chunk 775, containing 1000 records
# Saved a chunk
# Loaded chunk 776, containing 1000 records
# Saved a chunk
# Loaded chunk 777, containing 1000 records
# Saved a chunk
# Loaded chunk 778, containing 1000 records
# Saved a chunk
# Loaded chunk 779, containing 1000 records
# Saved a chunk
# Loaded chunk 780, containing 1000 records
# Saved a chunk
# Loaded chunk 781, containing 1000 records
# Saved a chunk
# Loaded chunk 782, containing 1000 records
# Saved a chunk
# Loaded chunk 783, containing 1000 records
# Saved a chunk
# Loaded chunk 784, containing 1000 records
# Saved a chunk
# Loaded chunk 785, containing 1000 records
# Saved a chunk
# Loaded chunk 786, containing 1000 records
# Saved a chunk
# Loaded chunk 787, containing 1000 records
# Saved a chunk
# Loaded chunk 788, containing 1000 records
# Saved a chunk
# Loaded chunk 789, containing 1000 records
# Saved a chunk
# Loaded chunk 790, containing 1000 records
# Saved a chunk
# Loaded chunk 791, containing 1000 records
# Saved a chunk
# Loaded chunk 792, containing 1000 records
# Saved a chunk
# Loaded chunk 793, containing 1000 records
# Saved a chunk
# Loaded chunk 794, containing 1000 records
# Saved a chunk
# Loaded chunk 795, containing 1000 records
# Saved a chunk
# Loaded chunk 796, containing 1000 records
# Saved a chunk
# Loaded chunk 797, containing 1000 records
# Saved a chunk
# Loaded chunk 798, containing 1000 records
# Saved a chunk
# Loaded chunk 799, containing 1000 records
# Saved a chunk
# Loaded chunk 800, containing 1000 records
# Saved a chunk
# Loaded chunk 801, containing 1000 records
# Saved a chunk
# Loaded chunk 802, containing 1000 records
# Saved a chunk
# Loaded chunk 803, containing 1000 records
# Saved a chunk
# Loaded chunk 804, containing 1000 records
# Saved a chunk
# Loaded chunk 805, containing 1000 records
# Saved a chunk
# Loaded chunk 806, containing 1000 records
# Saved a chunk
# Loaded chunk 807, containing 1000 records
# Saved a chunk
# Loaded chunk 808, containing 1000 records
# Saved a chunk
# Loaded chunk 809, containing 1000 records
# Saved a chunk
# Loaded chunk 810, containing 1000 records
# Saved a chunk
# Loaded chunk 811, containing 1000 records
# Saved a chunk
# Loaded chunk 812, containing 1000 records
# Saved a chunk
# Loaded chunk 813, containing 1000 records
# Saved a chunk
# Loaded chunk 814, containing 1000 records
# Saved a chunk
# Loaded chunk 815, containing 1000 records
# Saved a chunk
# Loaded chunk 816, containing 1000 records
# Saved a chunk
# Loaded chunk 817, containing 1000 records
# Saved a chunk
# Loaded chunk 818, containing 1000 records
# Saved a chunk
# Loaded chunk 819, containing 1000 records
# Saved a chunk
# Loaded chunk 820, containing 1000 records
# Saved a chunk
# Loaded chunk 821, containing 1000 records
# Saved a chunk
# Loaded chunk 822, containing 1000 records
# Saved a chunk
# Loaded chunk 823, containing 1000 records
# Saved a chunk
# Loaded chunk 824, containing 1000 records
# Saved a chunk
# Loaded chunk 825, containing 1000 records
# Saved a chunk
# Loaded chunk 826, containing 1000 records
# Saved a chunk
# Loaded chunk 827, containing 1000 records
# Saved a chunk
# Loaded chunk 828, containing 1000 records
# Saved a chunk
# Loaded chunk 829, containing 1000 records
# Saved a chunk
# Loaded chunk 830, containing 1000 records
# Saved a chunk
# Loaded chunk 831, containing 1000 records
# Saved a chunk
# Loaded chunk 832, containing 1000 records
# Saved a chunk
# Loaded chunk 833, containing 1000 records
# Saved a chunk
# Loaded chunk 834, containing 1000 records
# Saved a chunk
# Loaded chunk 835, containing 1000 records
# Saved a chunk
# Loaded chunk 836, containing 1000 records
# Saved a chunk
# Loaded chunk 837, containing 1000 records
# Saved a chunk
# Loaded chunk 838, containing 1000 records
# Saved a chunk
# Loaded chunk 839, containing 1000 records
# Saved a chunk
# Loaded chunk 840, containing 1000 records
# Saved a chunk
# Loaded chunk 841, containing 1000 records
# Saved a chunk
# Loaded chunk 842, containing 1000 records
# Saved a chunk
# Loaded chunk 843, containing 1000 records
# Saved a chunk
# Loaded chunk 844, containing 1000 records
# Saved a chunk
# Loaded chunk 845, containing 1000 records
# Saved a chunk
# Loaded chunk 846, containing 1000 records
# Saved a chunk
# Loaded chunk 847, containing 1000 records
# Saved a chunk
# Loaded chunk 848, containing 1000 records
# Saved a chunk
# Loaded chunk 849, containing 1000 records
# Saved a chunk
# Loaded chunk 850, containing 1000 records
# Saved a chunk
# Loaded chunk 851, containing 1000 records
# Saved a chunk
# Loaded chunk 852, containing 1000 records
# Saved a chunk
# Loaded chunk 853, containing 1000 records
# Saved a chunk
# Loaded chunk 854, containing 1000 records
# Saved a chunk
# Loaded chunk 855, containing 1000 records
# Saved a chunk
# Loaded chunk 856, containing 1000 records
# Saved a chunk
# Loaded chunk 857, containing 1000 records
# Saved a chunk
# Loaded chunk 858, containing 1000 records
# Saved a chunk
# ...
# Saved a chunk
# Loaded chunk 3979, containing 1000 records
# Saved a chunk
# Loaded chunk 3980, containing 1000 records
# Saved a chunk
# Loaded chunk 3981, containing 1000 records
# Saved a chunk
# Loaded chunk 3982, containing 1000 records
# Saved a chunk
# Loaded chunk 3983, containing 1000 records
# Saved a chunk
# Loaded chunk 3984, containing 1000 records
# Saved a chunk
# Loaded chunk 3985, containing 1000 records
# Saved a chunk
# Loaded chunk 3986, containing 1000 records
# Saved a chunk
# Loaded chunk 3987, containing 1000 records
# Saved a chunk
# Loaded chunk 3988, containing 1000 records
# Saved a chunk
# Loaded chunk 3989, containing 1000 records
# Saved a chunk
# Loaded chunk 3990, containing 1000 records
# Saved a chunk
# Loaded chunk 3991, containing 1000 records
# Saved a chunk
# Loaded chunk 3992, containing 1000 records
# Saved a chunk
# Loaded chunk 3993, containing 1000 records
# Saved a chunk
# Loaded chunk 3994, containing 1000 records
# Saved a chunk
# Loaded chunk 3995, containing 1000 records
# Saved a chunk
# Loaded chunk 3996, containing 1000 records
# Saved a chunk
# Loaded chunk 3997, containing 1000 records
# Saved a chunk
# Loaded chunk 3998, containing 1000 records
# Saved a chunk
# Loaded chunk 3999, containing 1000 records
# Saved a chunk
# Loaded chunk 4000, containing 1000 records
# Saved a chunk
# Loaded chunk 4001, containing 1000 records
# Saved a chunk
# Loaded chunk 4002, containing 1000 records
# Saved a chunk
# Loaded chunk 4003, containing 1000 records
# Saved a chunk
# Loaded chunk 4004, containing 1000 records
# Saved a chunk
# Loaded chunk 4005, containing 1000 records
# Saved a chunk
# Loaded chunk 4006, containing 1000 records
# Saved a chunk
# Loaded chunk 4007, containing 1000 records
# Saved a chunk
# Loaded chunk 4008, containing 1000 records
# Saved a chunk
# Loaded chunk 4009, containing 1000 records
# Saved a chunk
# Loaded chunk 4010, containing 1000 records
# Saved a chunk
# Loaded chunk 4011, containing 1000 records
# Saved a chunk
# Loaded chunk 4012, containing 1000 records
# Saved a chunk
# Loaded chunk 4013, containing 1000 records
# Saved a chunk
# Loaded chunk 4014, containing 1000 records
# Saved a chunk
# Loaded chunk 4015, containing 1000 records
# Saved a chunk
# Loaded chunk 4016, containing 1000 records
# Saved a chunk
# Loaded chunk 4017, containing 1000 records
# Saved a chunk
# Loaded chunk 4018, containing 1000 records
# Saved a chunk
# Loaded chunk 4019, containing 1000 records
# Saved a chunk
# Loaded chunk 4020, containing 1000 records
# Saved a chunk
# Loaded chunk 4021, containing 1000 records
# Saved a chunk
# Loaded chunk 4022, containing 1000 records
# Saved a chunk
# Loaded chunk 4023, containing 1000 records
# Saved a chunk
# Loaded chunk 4024, containing 1000 records
# Saved a chunk
# Loaded chunk 4025, containing 1000 records
# Saved a chunk
# Loaded chunk 4026, containing 1000 records
# Saved a chunk
# Loaded chunk 4027, containing 1000 records
# Saved a chunk
# Loaded chunk 4028, containing 1000 records
# Saved a chunk
# Loaded chunk 4029, containing 1000 records
# Saved a chunk
# Loaded chunk 4030, containing 1000 records
# Saved a chunk
# Loaded chunk 4031, containing 1000 records
# Saved a chunk
# Loaded chunk 4032, containing 1000 records
# Saved a chunk
# Loaded chunk 4033, containing 1000 records
# Saved a chunk
# Loaded chunk 4034, containing 1000 records
# Saved a chunk
# Loaded chunk 4035, containing 1000 records
# Saved a chunk
# Loaded chunk 4036, containing 1000 records
# Saved a chunk
# Loaded chunk 4037, containing 1000 records
# Saved a chunk
# Loaded chunk 4038, containing 1000 records
# Saved a chunk
# Loaded chunk 4039, containing 1000 records
# Saved a chunk
# Loaded chunk 4040, containing 1000 records
# Saved a chunk
# Loaded chunk 4041, containing 1000 records
# Saved a chunk
# Loaded chunk 4042, containing 1000 records
# Saved a chunk
# Loaded chunk 4043, containing 1000 records
# Saved a chunk
# Loaded chunk 4044, containing 1000 records
# Saved a chunk
# Loaded chunk 4045, containing 1000 records
# Saved a chunk
# Loaded chunk 4046, containing 1000 records
# Saved a chunk
# Loaded chunk 4047, containing 1000 records
# Saved a chunk
# Loaded chunk 4048, containing 1000 records
# Saved a chunk
# Loaded chunk 4049, containing 1000 records
# Saved a chunk
# Loaded chunk 4050, containing 1000 records
# Saved a chunk
# Loaded chunk 4051, containing 1000 records
# Saved a chunk
# Loaded chunk 4052, containing 1000 records
# Saved a chunk
# Loaded chunk 4053, containing 1000 records
# Saved a chunk
# Loaded chunk 4054, containing 1000 records
# Saved a chunk
# Loaded chunk 4055, containing 1000 records
# Saved a chunk
# Loaded chunk 4056, containing 1000 records
# Saved a chunk
# Loaded chunk 4057, containing 1000 records
# Saved a chunk
# Loaded chunk 4058, containing 1000 records
# Saved a chunk
# Loaded chunk 4059, containing 1000 records
# Saved a chunk
# Loaded chunk 4060, containing 1000 records
# Saved a chunk
# Loaded chunk 4061, containing 1000 records
# Saved a chunk
# Loaded chunk 4062, containing 1000 records
# Saved a chunk
# Loaded chunk 4063, containing 1000 records
# Saved a chunk
# Loaded chunk 4064, containing 1000 records
# Saved a chunk
# Loaded chunk 4065, containing 1000 records
# Saved a chunk
# Loaded chunk 4066, containing 1000 records
# Saved a chunk
# Loaded chunk 4067, containing 1000 records
# Saved a chunk
# Loaded chunk 4068, containing 1000 records
# Saved a chunk
# Loaded chunk 4069, containing 1000 records
# Saved a chunk
# Loaded chunk 4070, containing 1000 records
# Saved a chunk
# Loaded chunk 4071, containing 1000 records
# Saved a chunk
# Loaded chunk 4072, containing 1000 records
# Saved a chunk
# Loaded chunk 4073, containing 1000 records
# Saved a chunk
# Loaded chunk 4074, containing 1000 records
# Saved a chunk
# Loaded chunk 4075, containing 1000 records
# Saved a chunk
# Loaded chunk 4076, containing 1000 records
# Saved a chunk
# Loaded chunk 4077, containing 1000 records
# Saved a chunk
# Loaded chunk 4078, containing 1000 records
# Saved a chunk
# Loaded chunk 4079, containing 1000 records
# Saved a chunk
# Loaded chunk 4080, containing 1000 records
# Saved a chunk
# Loaded chunk 4081, containing 1000 records
# Saved a chunk
# Loaded chunk 4082, containing 1000 records
# Saved a chunk
# Loaded chunk 4083, containing 1000 records
# Saved a chunk
# Loaded chunk 4084, containing 1000 records
# Saved a chunk
# Loaded chunk 4085, containing 1000 records
# Saved a chunk
# Loaded chunk 4086, containing 1000 records
# Saved a chunk
# Loaded chunk 4087, containing 1000 records
# Saved a chunk
# Loaded chunk 4088, containing 1000 records
# Saved a chunk
# Loaded chunk 4089, containing 1000 records
# Saved a chunk
# Loaded chunk 4090, containing 1000 records
# Saved a chunk
# Loaded chunk 4091, containing 1000 records
# Saved a chunk
# Loaded chunk 4092, containing 1000 records
# Saved a chunk
# Loaded chunk 4093, containing 1000 records
# Saved a chunk
# Loaded chunk 4094, containing 1000 records
# Saved a chunk
# Loaded chunk 4095, containing 1000 records
# Saved a chunk
# Loaded chunk 4096, containing 1000 records
# Saved a chunk
# Loaded chunk 4097, containing 1000 records
# Saved a chunk
# Loaded chunk 4098, containing 1000 records
# Saved a chunk
# Loaded chunk 4099, containing 1000 records
# Saved a chunk
# Loaded chunk 4100, containing 1000 records
# Saved a chunk
# Loaded chunk 4101, containing 1000 records
# Saved a chunk
# Loaded chunk 4102, containing 1000 records
# Saved a chunk
# Loaded chunk 4103, containing 1000 records
# Saved a chunk
# Loaded chunk 4104, containing 1000 records
# Saved a chunk
# Loaded chunk 4105, containing 1000 records
# Saved a chunk
# Loaded chunk 4106, containing 1000 records
# Saved a chunk
# Loaded chunk 4107, containing 1000 records
# Saved a chunk
# Loaded chunk 4108, containing 1000 records
# Saved a chunk
# Loaded chunk 4109, containing 1000 records
# Saved a chunk
# Loaded chunk 4110, containing 1000 records
# Saved a chunk
# Loaded chunk 4111, containing 1000 records
# Saved a chunk
# Loaded chunk 4112, containing 1000 records
# Saved a chunk
# Loaded chunk 4113, containing 1000 records
# Saved a chunk
# Loaded chunk 4114, containing 1000 records
# Saved a chunk
# Loaded chunk 4115, containing 1000 records
# Saved a chunk
# Loaded chunk 4116, containing 1000 records
# Saved a chunk
# Loaded chunk 4117, containing 1000 records
# Saved a chunk
# Loaded chunk 4118, containing 1000 records
# Saved a chunk
# Loaded chunk 4119, containing 1000 records
# Saved a chunk
# Loaded chunk 4120, containing 1000 records
# Saved a chunk
# Loaded chunk 4121, containing 1000 records
# Saved a chunk
# Loaded chunk 4122, containing 1000 records
# Saved a chunk
# Loaded chunk 4123, containing 1000 records
# Saved a chunk
# Loaded chunk 4124, containing 1000 records
# Saved a chunk
# Loaded chunk 4125, containing 1000 records
# Saved a chunk
# Loaded chunk 4126, containing 1000 records
# Saved a chunk
# Loaded chunk 4127, containing 1000 records
# Saved a chunk
# Loaded chunk 4128, containing 1000 records
# Saved a chunk
# Loaded chunk 4129, containing 1000 records
# Saved a chunk
# Loaded chunk 4130, containing 1000 records
# Saved a chunk
# Loaded chunk 4131, containing 1000 records
# Saved a chunk
# Loaded chunk 4132, containing 1000 records
# Saved a chunk
# Loaded chunk 4133, containing 1000 records
# Saved a chunk
# Loaded chunk 4134, containing 1000 records
# Saved a chunk
# Loaded chunk 4135, containing 1000 records
# Saved a chunk
# Loaded chunk 4136, containing 1000 records
# Saved a chunk
# Loaded chunk 4137, containing 1000 records
# Saved a chunk
# Loaded chunk 4138, containing 1000 records
# Saved a chunk
# Loaded chunk 4139, containing 1000 records
# Saved a chunk
# Loaded chunk 4140, containing 1000 records
# Saved a chunk
# Loaded chunk 4141, containing 1000 records
# Saved a chunk
# Loaded chunk 4142, containing 1000 records
# Saved a chunk
# Loaded chunk 4143, containing 1000 records
# Saved a chunk
# Loaded chunk 4144, containing 1000 records
# Saved a chunk
# Loaded chunk 4145, containing 1000 records
# Saved a chunk
# Loaded chunk 4146, containing 1000 records
# Saved a chunk
# Loaded chunk 4147, containing 1000 records
# Saved a chunk
# Loaded chunk 4148, containing 1000 records
# Saved a chunk
# Loaded chunk 4149, containing 1000 records
# Saved a chunk
# Loaded chunk 4150, containing 1000 records
# Saved a chunk
# Loaded chunk 4151, containing 1000 records
# Saved a chunk
# Loaded chunk 4152, containing 1000 records
# Saved a chunk
# Loaded chunk 4153, containing 1000 records
# Saved a chunk
# Loaded chunk 4154, containing 1000 records
# Saved a chunk
# Loaded chunk 4155, containing 1000 records
# Saved a chunk
# Loaded chunk 4156, containing 1000 records
# Saved a chunk
# Loaded chunk 4157, containing 1000 records
# Saved a chunk
# Loaded chunk 4158, containing 1000 records
# Saved a chunk
# Loaded chunk 4159, containing 1000 records
# Saved a chunk
# Loaded chunk 4160, containing 1000 records
# Saved a chunk
# Loaded chunk 4161, containing 1000 records
# Saved a chunk
# Loaded chunk 4162, containing 1000 records
# Saved a chunk
# Loaded chunk 4163, containing 1000 records
# Saved a chunk
# Loaded chunk 4164, containing 1000 records
# Saved a chunk
# Loaded chunk 4165, containing 1000 records
# Saved a chunk
# Loaded chunk 4166, containing 1000 records
# Saved a chunk
# Loaded chunk 4167, containing 1000 records
# Saved a chunk
# Loaded chunk 4168, containing 1000 records
# Saved a chunk
# Loaded chunk 4169, containing 1000 records
# Saved a chunk
# Loaded chunk 4170, containing 1000 records
# Saved a chunk
# Loaded chunk 4171, containing 1000 records
# Saved a chunk
# Loaded chunk 4172, containing 1000 records
# Saved a chunk
# Loaded chunk 4173, containing 1000 records
# Saved a chunk
# Loaded chunk 4174, containing 1000 records
# Saved a chunk
# Loaded chunk 4175, containing 1000 records
# Saved a chunk
# Loaded chunk 4176, containing 1000 records
# Saved a chunk
# Loaded chunk 4177, containing 1000 records
# Saved a chunk
# Loaded chunk 4178, containing 1000 records
# Saved a chunk
# Loaded chunk 4179, containing 1000 records
# Saved a chunk
# Loaded chunk 4180, containing 1000 records
# Saved a chunk
# Loaded chunk 4181, containing 1000 records
# Saved a chunk
# Loaded chunk 4182, containing 1000 records
# Saved a chunk
# Loaded chunk 4183, containing 1000 records
# Saved a chunk
# Loaded chunk 4184, containing 1000 records
# Saved a chunk
# Loaded chunk 4185, containing 1000 records
# Saved a chunk
# Loaded chunk 4186, containing 1000 records
# Saved a chunk
# Loaded chunk 4187, containing 1000 records
# Saved a chunk
# Loaded chunk 4188, containing 1000 records
# Saved a chunk
# Loaded chunk 4189, containing 1000 records
# Saved a chunk
# Loaded chunk 4190, containing 1000 records
# Saved a chunk
# Loaded chunk 4191, containing 1000 records
# Saved a chunk
# Loaded chunk 4192, containing 1000 records
# Saved a chunk
# Loaded chunk 4193, containing 1000 records
# Saved a chunk
# Loaded chunk 4194, containing 1000 records
# Saved a chunk
# Loaded chunk 4195, containing 1000 records
# Saved a chunk
# Loaded chunk 4196, containing 1000 records
# Saved a chunk
# Loaded chunk 4197, containing 1000 records
# Saved a chunk
# Loaded chunk 4198, containing 1000 records
# Saved a chunk
# Loaded chunk 4199, containing 1000 records
# Saved a chunk
# Loaded chunk 4200, containing 1000 records
# Saved a chunk
# Loaded chunk 4201, containing 1000 records
# Saved a chunk
# Loaded chunk 4202, containing 1000 records
# Saved a chunk
# Loaded chunk 4203, containing 1000 records
# Saved a chunk
# Loaded chunk 4204, containing 1000 records
# Saved a chunk
# Loaded chunk 4205, containing 1000 records
# Saved a chunk
# Loaded chunk 4206, containing 1000 records
# Saved a chunk
# Loaded chunk 4207, containing 1000 records
# Saved a chunk
# Loaded chunk 4208, containing 1000 records
# Saved a chunk
# Loaded chunk 4209, containing 1000 records
# Saved a chunk
# Loaded chunk 4210, containing 1000 records
# Saved a chunk
# Loaded chunk 4211, containing 1000 records
# Saved a chunk
# Loaded chunk 4212, containing 1000 records
# Saved a chunk
# Loaded chunk 4213, containing 1000 records
# Saved a chunk
# Loaded chunk 4214, containing 1000 records
# Saved a chunk
# Loaded chunk 4215, containing 1000 records
# Saved a chunk
# Loaded chunk 4216, containing 1000 records
# Saved a chunk
# Loaded chunk 4217, containing 1000 records
# Saved a chunk
# Loaded chunk 4218, containing 1000 records
# Saved a chunk
# Loaded chunk 4219, containing 1000 records
# Saved a chunk
# Loaded chunk 4220, containing 1000 records
# Saved a chunk
# Loaded chunk 4221, containing 1000 records
# Saved a chunk
# Loaded chunk 4222, containing 1000 records
# Saved a chunk
# Loaded chunk 4223, containing 1000 records
# Saved a chunk
# Loaded chunk 4224, containing 1000 records
# Saved a chunk
# Loaded chunk 4225, containing 1000 records
# Saved a chunk
# Loaded chunk 4226, containing 1000 records
# Saved a chunk
# Loaded chunk 4227, containing 1000 records
# Saved a chunk
# Loaded chunk 4228, containing 1000 records
# Saved a chunk
# Loaded chunk 4229, containing 1000 records
# Saved a chunk
# Loaded chunk 4230, containing 1000 records
# Saved a chunk
# Loaded chunk 4231, containing 1000 records
# Saved a chunk
# Loaded chunk 4232, containing 1000 records
# Saved a chunk
# Loaded chunk 4233, containing 1000 records
# Saved a chunk
# Loaded chunk 4234, containing 1000 records
# Saved a chunk
# Loaded chunk 4235, containing 1000 records
# Saved a chunk
# Loaded chunk 4236, containing 1000 records
# Saved a chunk
# Loaded chunk 4237, containing 1000 records
# Saved a chunk
# Loaded chunk 4238, containing 1000 records
# Saved a chunk
# Loaded chunk 4239, containing 1000 records
# Saved a chunk
# Loaded chunk 4240, containing 1000 records
# Saved a chunk
# Loaded chunk 4241, containing 1000 records
# Saved a chunk
# Loaded chunk 4242, containing 1000 records
# Saved a chunk
# Loaded chunk 4243, containing 1000 records
# Saved a chunk
# Loaded chunk 4244, containing 1000 records
# Saved a chunk
# Loaded chunk 4245, containing 1000 records
# Saved a chunk
# Loaded chunk 4246, containing 1000 records
# Saved a chunk
# Loaded chunk 4247, containing 1000 records
# Saved a chunk
# Loaded chunk 4248, containing 1000 records
# Saved a chunk
# Loaded chunk 4249, containing 1000 records
# Saved a chunk
# Loaded chunk 4250, containing 1000 records
# Saved a chunk
# Loaded chunk 4251, containing 1000 records
# Saved a chunk
# Loaded chunk 4252, containing 1000 records
# Saved a chunk
# Loaded chunk 4253, containing 1000 records
# Saved a chunk
# Loaded chunk 4254, containing 1000 records
# Saved a chunk
# Loaded chunk 4255, containing 1000 records
# Saved a chunk
# Loaded chunk 4256, containing 1000 records
# Saved a chunk
# Loaded chunk 4257, containing 1000 records
# Saved a chunk
# Loaded chunk 4258, containing 297 records
# Saved a chunk

# %%
col.create_index('doc_companieshouseregisterednumber')
# Out:
# 'doc_companieshouseregisterednumber_1'

# %% [markdown]
# ## Determine whether, for each file with no digital record, a paper record was submitted
#
# For each entry in the "doesn't have an electronic record" csv file, see if it has a paper record instead by querying the Companies House API.  Record the date of the entry.

# %%
counter = 0

for chunk in pd.read_csv("./output/CH_no_digital_records.csv", chunksize=100):
    
    results = pd.DataFrame()
    
    for index, row in chunk.iterrows():
        
        # Wait for 2/10th of a second - this to accomodate rate limiting by CH to 600 requests/minute
        tic.sleep(.2)
        
        r = requests.get(information_url.format(row[' CompanyNumber']), auth=(key, ""))

        doc_dates = []
            
        try:
            for each in r.json()['items']:
    
                if each['type'] == "AA":
                    doc_dates.append( each['date'])
        
            row['num_paper_records'] = len(doc_dates)
            row['paper_record_dates'] = ":".join(doc_dates)
            row['response_code'] = r.status_code
            
            results = results.append(row, ignore_index=True)
            
        except:
            row['num_paper_records'] = None
            row['paper_record_dates'] = None
            row['response_code'] = r.status_code
            
            results = results.append(row, ignore_index=True)

    # Append the discovered missing DB entries to the output csv file
    if (counter > 0) & (len(chunk) > 0):
        with open("./output/CH_no_digital_records_searched.csv", 'a') as f:
            results.to_csv(f, mode='a', header=False, index=False)
            print("Saved a chunk.  Reporting latest:", r.status_code, doc_dates)
    
    # Create a csv file for the discovered missing DB entries if one doesn't exist yet
    else:
        results.to_csv("./output/CH_no_digital_records_searched.csv", index=False)
        print("Saved first chunk")
    
    counter += 1
# Out:
# Saved first chunk
# Saved a chunk.  Reporting latest: 200 ['2018-05-01']
# Saved a chunk.  Reporting latest: 200 ['2018-08-22', '2017-07-17', '2016-08-11', '2015-09-08', '2014-05-15', '2013-05-31', '2012-06-19', '2011-04-06', '2010-08-12', '2009-06-07', '2008-03-31']
# Saved a chunk.  Reporting latest: 200 ['2011-11-22', '2010-11-22', '2010-03-30', '2009-01-08', '2008-06-17']
# Saved a chunk.  Reporting latest: 200 []
# Saved a chunk.  Reporting latest: 200 []
# Saved a chunk.  Reporting latest: 200 ['2012-01-17', '2010-12-08', '2009-11-28', '2008-10-24', '2007-12-11', '2006-12-06']
# Saved a chunk.  Reporting latest: 200 []
# Saved a chunk.  Reporting latest: 200 []
# Saved a chunk.  Reporting latest: 200 ['2006-11-05']
# Saved a chunk.  Reporting latest: 429 []
# Saved a chunk.  Reporting latest: 429 []
# Saved a chunk.  Reporting latest: 200 ['2018-11-04', '2018-03-21', '2016-08-10']
