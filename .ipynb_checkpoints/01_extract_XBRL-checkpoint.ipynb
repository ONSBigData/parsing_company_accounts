# %% [markdown]
# # Extracting Data from Companies House Electronic Records
#
# Companies house receives 75% of its records in XBRL or iXBRL format, a glorified tagged xml document that should allow for easy automated extraction of statistics.
#
# The software in this repo was developed after reading of this (American) example:
# https://www.codeproject.com/Articles/1227765/Parsing-XBRL-with-Python
#
# The functions for doing so are hosted in the module xbrl_parser.py
#
# Both xbrl_parser.py and this script have a number of python package dependencies so expect to have to install some things.

# %% [markdown]
# ## Returned dict schema for html/xml sourced data
#
# A practical note:  Apart from explicitly elevated metadata, all extracted values are stored in a list of "elements" within the returned dict.  Each element is itself a dict, containing the name and value of the discovered data along with fields unit and date for metadata.

# %% [markdown]
# # Setup (import modules, set up a helper function for getting filepaths)

# %%
import xbrl_parser as xp
import os
import numpy as np
import pandas as pd
import importlib

def get_filepaths(directory):

    """ Helper function - 
    Get all of the filenames in a directory that
    end in htm* or xml.
    Under the assumption that all files within
    the folder are financial records. """

    files = [directory + "/" + filename
                for filename in os.listdir(directory)
                    if (("htm" in filename.lower()) or ("xml" in filename.lower())) ]
    return(files)

# %% [markdown]
# # Extracting data from documents
#
# We'll import the module, and process some files

# %%
# Get all the filenames from the example folder
files = get_filepaths("./example_data_XBRL_iXBRL")

# There's 379 examples currently
files[0:7]
# Out:
# ['./example_data_XBRL_iXBRL/Prod224_0042_00958610_20160930.xml',
#  './example_data_XBRL_iXBRL/Prod223_2125_09749826_20170831.html',
#  './example_data_XBRL_iXBRL/Prod223_2125_09170142_20170831.html',
#  './example_data_XBRL_iXBRL/Prod224_0042_03237381_20160831.xml',
#  './example_data_XBRL_iXBRL/Prod223_2125_09900460_20161231.html',
#  './example_data_XBRL_iXBRL/Prod223_2125_09652609_20180331.html',
#  './example_data_XBRL_iXBRL/Prod223_2125_09722743_20170831.html']

# %%
# Reload the xbrl_parser module (don't need this normally, it's just useful for me
# for iterative testing of changes)
importlib.reload(xp)

# try getting the first file (an XML, or XBRL, file)
doc = xp.process_account(files[0])

# display for fun
doc
# Out:
# ./example_data_XBRL_iXBRL/Prod224_0042_00958610_20160930.xml
# {'doc_name': 'Prod224_0042_00958610_20160930.xml',
#  'doc_type': 'xml',
#  'doc_upload_date': '2019-02-19 16:32:22.789529',
#  'arc_name': 'example_data_XBRL_iXBRL',
#  'parsed': True,
#  'doc_balancesheetdate': '2016-09-30',
#  'doc_companieshouseregisterednumber': '00958610',
#  'doc_standard_type': 'uk-gaap-ae',
#  'doc_standard_date': '2009-06-21',
#  'doc_standard_link': 'http://www.companieshouse.gov.uk/ef/xbrl/uk/fr/gaap/ae/2009-06-21/uk-gaap-ae-2009-06-21.xsd',
#  'elements': [{'name': 'companynotdormant',
#    'value': 'true',
#    'unit': 'NA',
#    'date': '2016-09-30'},
#   {'name': 'entitycurrentlegalname',
#    'value': 'S.L.M. (Model) Engineers Limited',
#    'unit': 'NA',
#    'date': '2016-09-30'},
#   {'name': 'companieshouseregisterednumber',
#    'value': '00958610',
#    'unit': 'NA',
#    'date': '2016-09-30'},
#   {'name': 'balancesheetdate',
#    'value': '2016-09-30',
#    'unit': 'NA',
#    'date': '2016-09-30'},
#   {'name': 'profitlossaccountreserve',
#    'value': 83402.0,
#    'unit': 'iso4217:GBP',
#    'date': '2016-09-30'},
#   {'name': 'profitlossaccountreserve',
#    'value': 76151.0,
#    'unit': 'iso4217:GBP',
#    'date': '2015-09-30'},
#   {'name': 'shareholderfunds',
#    'value': 88402.0,
#    'unit': 'iso4217:GBP',
#    'date': '2016-09-30'},
#   {'name': 'shareholderfunds',
#    'value': 81151.0,
#    'unit': 'iso4217:GBP',
#    'date': '2015-09-30'},
#   {'name': 'calledupsharecapital',
#    'value': 5000.0,
#    'unit': 'iso4217:GBP',
#    'date': '2016-09-30'},
#   {'name': 'calledupsharecapital',
#    'value': 5000.0,
#    'unit': 'iso4217:GBP',
#    'date': '2015-09-30'},
#   {'name': 'netassetsliabilitiesincludingpensionassetliability',
#    'value': 88402.0,
#    'unit': 'iso4217:GBP',
#    'date': '2016-09-30'},
#   {'name': 'netassetsliabilitiesincludingpensionassetliability',
#    'value': 81151.0,
#    'unit': 'iso4217:GBP',
#    'date': '2015-09-30'},
#   {'name': 'provisionsforliabilitiescharges',
#    'value': 0.0,
#    'unit': 'iso4217:GBP',
#    'date': '2016-09-30'},
#   {'name': 'provisionsforliabilitiescharges',
#    'value': 6575.0,
#    'unit': 'iso4217:GBP',
#    'date': '2015-09-30'},
#   {'name': 'totalassetslesscurrentliabilities',
#    'value': 88402.0,
#    'unit': 'iso4217:GBP',
#    'date': '2016-09-30'},
#   {'name': 'totalassetslesscurrentliabilities',
#    'value': 87726.0,
#    'unit': 'iso4217:GBP',
#    'date': '2015-09-30'},
#   {'name': 'netcurrentassetsliabilities',
#    'value': -17387.0,
#    'unit': 'iso4217:GBP',
#    'date': '2016-09-30'},
#   {'name': 'netcurrentassetsliabilities',
#    'value': -21381.0,
#    'unit': 'iso4217:GBP',
#    'date': '2015-09-30'},
#   {'name': 'creditorsduewithinoneyeartotalcurrentliabilities',
#    'value': 257865.0,
#    'unit': 'iso4217:GBP',
#    'date': '2016-09-30'},
#   {'name': 'creditorsduewithinoneyeartotalcurrentliabilities',
#    'value': 270286.0,
#    'unit': 'iso4217:GBP',
#    'date': '2015-09-30'},
#   {'name': 'currentassets',
#    'value': 240478.0,
#    'unit': 'iso4217:GBP',
#    'date': '2016-09-30'},
#   {'name': 'currentassets',
#    'value': 248905.0,
#    'unit': 'iso4217:GBP',
#    'date': '2015-09-30'},
#   {'name': 'debtors',
#    'value': 181072.0,
#    'unit': 'iso4217:GBP',
#    'date': '2016-09-30'},
#   {'name': 'debtors',
#    'value': 184636.0,
#    'unit': 'iso4217:GBP',
#    'date': '2015-09-30'},
#   {'name': 'stocksinventory',
#    'value': 6678.0,
#    'unit': 'iso4217:GBP',
#    'date': '2016-09-30'},
#   {'name': 'stocksinventory',
#    'value': 7774.0,
#    'unit': 'iso4217:GBP',
#    'date': '2015-09-30'},
#   {'name': 'cashbankinhand',
#    'value': 52728.0,
#    'unit': 'iso4217:GBP',
#    'date': '2016-09-30'},
#   {'name': 'cashbankinhand',
#    'value': 56495.0,
#    'unit': 'iso4217:GBP',
#    'date': '2015-09-30'},
#   {'name': 'fixedassets',
#    'value': 105789.0,
#    'unit': 'iso4217:GBP',
#    'date': '2016-09-30'},
#   {'name': 'fixedassets',
#    'value': 109107.0,
#    'unit': 'iso4217:GBP',
#    'date': '2015-09-30'},
#   {'name': 'tangiblefixedassets',
#    'value': 105789.0,
#    'unit': 'iso4217:GBP',
#    'date': '2016-09-30'},
#   {'name': 'tangiblefixedassets',
#    'value': 109107.0,
#    'unit': 'iso4217:GBP',
#    'date': '2015-09-30'},
#   {'name': 'titleaccountingpolicy',
#    'value': 'Basis of accounting\n',
#    'unit': 'NA',
#    'date': '2016-09-30'},
#   {'name': 'contentaccountingpolicy',
#    'value': 'The financial statements have been prepared under the historical cost convention, and in accordance with the Financial Reporting Standard for Smaller  Entities (effective April 2008).\n',
#    'unit': 'NA',
#    'date': '2016-09-30'},
#   {'name': 'titleaccountingpolicy',
#    'value': 'Turnover\n',
#    'unit': 'NA',
#    'date': '2016-09-30'},
#   {'name': 'contentaccountingpolicy',
#    'value': 'The turnover shown in the profit and loss account represents amounts invoiced during the year, exclusive of Value Added Tax.\n',
#    'unit': 'NA',
#    'date': '2016-09-30'},
#   {'name': 'titleaccountingpolicy',
#    'value': 'Stocks\n',
#    'unit': 'NA',
#    'date': '2016-09-30'},
#   {'name': 'contentaccountingpolicy',
#    'value': 'Stocks are valued at the lower of cost and net realisable value, after making due allowance\nfor obsolete and slow moving items.\n',
#    'unit': 'NA',
#    'date': '2016-09-30'},
#   {'name': 'titleaccountingpolicy',
#    'value': 'Pension costs\n',
#    'unit': 'NA',
#    'date': '2016-09-30'},
#   {'name': 'contentaccountingpolicy',
#    'value': 'The company operates a defined contribution pension scheme for employees. The assets of the scheme are held separately from those of the company. The  annual contributions payable are charged to the profit and loss account.\n',
#    'unit': 'NA',
#    'date': '2016-09-30'},
#   {'name': 'titleaccountingpolicy',
#    'value': 'Deferred taxation\n',
#    'unit': 'NA',
#    'date': '2016-09-30'},
#   {'name': 'contentaccountingpolicy',
#    'value': 'Deferred tax is recognised in respect of all timing differences that have originated but not\nreversed at the balance sheet date where transactions or events have occurred at that date that\nwill result in an obligation to pay more, or a right to pay less or to receive more tax, with\nthe following exceptions:\nProvision is made for tax on gains arising from the revaluation (and similar fair value adjustments)\nof fixed assets, and gains on disposal of fixed assets that have been rolled over into replacement\nassets, only to the extent that, at the balance sheet date, there is a binding agreement to dispose\nof the assets concerned. However, no provision is made where, on the basis of all available\nevidence at the balance sheet date, it is more likely than not that the taxable gain will be rolled\nover into replacement assets and charged to tax only where the replacement assets are sold.\nDeferred tax assets are recognised only to the extent that the director considers that it is more\nlikely than not that there will be suitable taxable profits from which the future reversal of the\nunderlying timing differences can be deducted.\nDeferred tax is measured on an undiscounted basis at the tax rates that are expected\nto apply in the periods in which timing differences reverse, based on tax rates and laws enacted or\nsubstantively enacted at the balance sheet date.\n',
#    'unit': 'NA',
#    'date': '2016-09-30'},
#   {'name': 'titleaccountingpolicy',
#    'value': 'Fixed Assets\n',
#    'unit': 'NA',
#    'date': '2016-09-30'},
#   {'name': 'contentaccountingpolicy',
#    'value': 'All fixed assets are initially recorded at cost.\n',
#    'unit': 'NA',
#    'date': '2016-09-30'},
#   {'name': 'categoryitem',
#    'value': 'Land & Buildings',
#    'unit': 'NA',
#    'date': '2016-09-30'},
#   {'name': 'typedepreciation',
#    'value': 'Method for Freehold property',
#    'unit': 'NA',
#    'date': '2016-09-30'},
#   {'name': 'ratedepreciation',
#    'value': 0.0,
#    'unit': 'xbrli:pure',
#    'date': '2016-09-30'},
#   {'name': 'categoryitem',
#    'value': 'Plant & Machinery',
#    'unit': 'NA',
#    'date': '2016-09-30'},
#   {'name': 'typedepreciation',
#    'value': 'Method for Plant & equipment',
#    'unit': 'NA',
#    'date': '2016-09-30'},
#   {'name': 'ratedepreciation',
#    'value': 0.0,
#    'unit': 'xbrli:pure',
#    'date': '2016-09-30'},
#   {'name': 'categoryitem',
#    'value': 'Fixtures & Fittings',
#    'unit': 'NA',
#    'date': '2016-09-30'},
#   {'name': 'typedepreciation',
#    'value': 'Method for Fixtures & fittings',
#    'unit': 'NA',
#    'date': '2016-09-30'},
#   {'name': 'ratedepreciation',
#    'value': 0.0,
#    'unit': 'xbrli:pure',
#    'date': '2016-09-30'},
#   {'name': 'categoryitem',
#    'value': 'Motor Vehicle',
#    'unit': 'NA',
#    'date': '2016-09-30'},
#   {'name': 'typedepreciation',
#    'value': 'Method for Motor vehicles',
#    'unit': 'NA',
#    'date': '2016-09-30'},
#   {'name': 'ratedepreciation',
#    'value': 0.0,
#    'unit': 'xbrli:pure',
#    'date': '2016-09-30'},
#   {'name': 'intangibleassetsfreetextnote',
#    'value': '',
#    'unit': 'NA',
#    'date': '2016-09-30'},
#   {'name': 'tangiblefixedassetscostorvaluation',
#    'value': 328193.0,
#    'unit': 'iso4217:GBP',
#    'date': '2016-09-30'},
#   {'name': 'tangiblefixedassetscostorvaluation',
#    'value': 325644.0,
#    'unit': 'iso4217:GBP',
#    'date': '2015-09-30'},
#   {'name': 'tangiblefixedassetsadditions',
#    'value': 2549.0,
#    'unit': 'iso4217:GBP',
#    'date': '2016-09-30'},
#   {'name': 'tangiblefixedassetsdepreciation',
#    'value': 222404.0,
#    'unit': 'iso4217:GBP',
#    'date': '2016-09-30'},
#   {'name': 'tangiblefixedassetsdepreciation',
#    'value': 216537.0,
#    'unit': 'iso4217:GBP',
#    'date': '2015-09-30'},
#   {'name': 'tangiblefixedassetsdepreciationchargeforperiod',
#    'value': 5867.0,
#    'unit': 'iso4217:GBP',
#    'date': '2016-09-30'},
#   {'name': 'tangibleassetsfreetextnote',
#    'value': '',
#    'unit': 'NA',
#    'date': '2016-09-30'},
#   {'name': 'investmentsfixedassetsfreetextnote',
#    'value': '',
#    'unit': 'NA',
#    'date': '2016-09-30'},
#   {'name': 'totalfixedassetscostorvaluation',
#    'value': 328193.0,
#    'unit': 'iso4217:GBP',
#    'date': '2016-09-30'},
#   {'name': 'totalfixedassetscostorvaluation',
#    'value': 325644.0,
#    'unit': 'iso4217:GBP',
#    'date': '2015-09-30'},
#   {'name': 'totalfixedassetsadditions',
#    'value': 2549.0,
#    'unit': 'iso4217:GBP',
#    'date': '2016-09-30'},
#   {'name': 'totalfixedassetsdepreciation',
#    'value': 222404.0,
#    'unit': 'iso4217:GBP',
#    'date': '2016-09-30'},
#   {'name': 'totalfixedassetsdepreciation',
#    'value': 216537.0,
#    'unit': 'iso4217:GBP',
#    'date': '2015-09-30'},
#   {'name': 'totalfixedassetsdepreciationchargeinperiod',
#    'value': 5867.0,
#    'unit': 'iso4217:GBP',
#    'date': '2016-09-30'},
#   {'name': 'totalfixedassetsfreetextnote',
#    'value': '',
#    'unit': 'NA',
#    'date': '2016-09-30'},
#   {'name': 'creditorsdueafteroneyearfreetextnote',
#    'value': '',
#    'unit': 'NA',
#    'date': '2016-09-30'},
#   {'name': 'typeordinaryshare',
#    'value': 'A ordinary',
#    'unit': 'NA',
#    'date': '2016-09-30'},
#   {'name': 'numberordinarysharesauthorised',
#    'value': 10000.0,
#    'unit': 'xbrli:shares',
#    'date': '2016-09-30'},
#   {'name': 'parvalueordinaryshare',
#    'value': 1.0,
#    'unit': 'iso4217:GBP',
#    'date': '2016-09-30'},
#   {'name': 'valueordinarysharesauthorised',
#    'value': 10000.0,
#    'unit': 'iso4217:GBP',
#    'date': '2016-09-30'},
#   {'name': 'valueordinarysharesauthorised',
#    'value': 10000.0,
#    'unit': 'iso4217:GBP',
#    'date': '2015-09-30'},
#   {'name': 'typeordinaryshare',
#    'value': 'B ordinary',
#    'unit': 'NA',
#    'date': '2016-09-30'},
#   {'name': 'numberordinarysharesauthorised',
#    'value': 10000.0,
#    'unit': 'xbrli:shares',
#    'date': '2016-09-30'},
#   {'name': 'parvalueordinaryshare',
#    'value': 1.0,
#    'unit': 'iso4217:GBP',
#    'date': '2016-09-30'},
#   {'name': 'valueordinarysharesauthorised',
#    'value': 10000.0,
#    'unit': 'iso4217:GBP',
#    'date': '2016-09-30'},
#   {'name': 'valueordinarysharesauthorised',
#    'value': 10000.0,
#    'unit': 'iso4217:GBP',
#    'date': '2015-09-30'},
#   {'name': 'typeordinaryshare',
#    'value': 'A ordinary',
#    'unit': 'NA',
#    'date': '2016-09-30'},
#   {'name': 'parvalueordinaryshare',
#    'value': 1.0,
#    'unit': 'iso4217:GBP',
#    'date': '2016-09-30'},
#   {'name': 'valueordinarysharesallotted',
#    'value': 4900.0,
#    'unit': 'iso4217:GBP',
#    'date': '2016-09-30'},
#   {'name': 'valueordinarysharesallotted',
#    'value': 4900.0,
#    'unit': 'iso4217:GBP',
#    'date': '2015-09-30'},
#   {'name': 'numberordinarysharesallotted',
#    'value': 4900.0,
#    'unit': 'xbrli:shares',
#    'date': '2016-09-30'},
#   {'name': 'typeordinaryshare',
#    'value': 'B ordinary',
#    'unit': 'NA',
#    'date': '2016-09-30'},
#   {'name': 'parvalueordinaryshare',
#    'value': 1.0,
#    'unit': 'iso4217:GBP',
#    'date': '2016-09-30'},
#   {'name': 'valueordinarysharesallotted',
#    'value': 100.0,
#    'unit': 'iso4217:GBP',
#    'date': '2016-09-30'},
#   {'name': 'valueordinarysharesallotted',
#    'value': 100.0,
#    'unit': 'iso4217:GBP',
#    'date': '2015-09-30'},
#   {'name': 'numberordinarysharesallotted',
#    'value': 100.0,
#    'unit': 'xbrli:shares',
#    'date': '2016-09-30'},
#   {'name': 'sharecapitalfreetextnote',
#    'value': '',
#    'unit': 'NA',
#    'date': '2016-09-30'},
#   {'name': 'dateapproval',
#    'value': '2017-05-23',
#    'unit': 'NA',
#    'date': '2016-09-30'},
#   {'name': 'nameapprovingdirector',
#    'value': 'Mr M Lewicki',
#    'unit': 'NA',
#    'date': '2016-09-30'},
#   {'name': 'companyentitledtoexemptionundersection477companiesact2006',
#    'value': 'true',
#    'unit': 'NA',
#    'date': '2016-09-30'},
#   {'name': 'membershavenotrequiredcompanytoobtainanaudit',
#    'value': 'true',
#    'unit': 'NA',
#    'date': '2016-09-30'},
#   {'name': 'directorsacknowledgetheirresponsibilitiesundercompaniesact',
#    'value': 'true',
#    'unit': 'NA',
#    'date': '2016-09-30'},
#   {'name': 'accountsareinaccordancewithspecialprovisionscompaniesactrelatingtosmallcompanies',
#    'value': 'true',
#    'unit': 'NA',
#    'date': '2016-09-30'},
#   {'name': 'companieshousedocumentauthentication',
#    'value': ' ',
#    'unit': 'NA',
#    'date': '2016-09-30'},
#   {'name': 'dateaccountsreceived',
#    'value': '2017-05-24',
#    'unit': 'NA',
#    'date': '2016-09-30'}]}

# %%
# try getting the second file (an HTML, or iXBRL, file)
doc2 = xp.process_account(files[1])

# display for fun
doc2
# Out:
# ./example_data_XBRL_iXBRL/Prod223_2125_09749826_20170831.html
# {'doc_name': 'Prod223_2125_09749826_20170831.html',
#  'doc_type': 'html',
#  'doc_upload_date': '2019-02-19 16:32:23.975956',
#  'arc_name': 'example_data_XBRL_iXBRL',
#  'parsed': True,
#  'doc_balancesheetdate': '2017-08-31',
#  'doc_companieshouseregisterednumber': '09749826',
#  'doc_standard_type': 'FRS-102',
#  'doc_standard_date': '2014-09-01',
#  'doc_standard_link': 'https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS-102-2014-09-01.xsd',
#  'elements': [{'name': 'nameproductionsoftware',
#    'value': 'Caseware UK (AP4) 2016.0.181',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'versionproductionsoftware',
#    'value': ' 2016.0.181',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'enddateforperiodcoveredbyreport',
#    'value': '2017-08-31',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'balancesheetdate',
#    'value': '2017-08-31',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'accountstypefullorabbreviated',
#    'value': 'FullAccounts',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'accountingstandardsapplied',
#    'value': 'FRS102',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'entitytradingstatus',
#    'value': '',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'descriptionprincipalactivities',
#    'value': 'No description of principal activity',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'accountsstatusauditedorunaudited',
#    'value': 'AuditExempt-NoAccountantsReport',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'entitydormanttruefalse',
#    'value': 'false',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'startdateforperiodcoveredbyreport',
#    'value': '2016-09-01',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'entityhastakenexemptionundercompaniesactinnotpublishingitsownprofitlossaccounttruefalse',
#    'value': 'true',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'entityhasclaimedexemptionfrompresentingcashflowstatementnotesinlinewithfrs1021.12btruefalse',
#    'value': 'true',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'statementthatmembershavenotrequiredcompanytoobtainanaudit',
#    'value': 'The members have not required the company to obtain an audit in accordance with section 476 of the Companies Act 2006.',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'legalformentity',
#    'value': 'PrivateLimitedCompanyLtd',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'ukcompanieshouseregisterednumber',
#    'value': '09749826',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'entitycurrentlegalorregisteredname',
#    'value': 'J T PLANT SALES LIMITED',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'nameentityofficer',
#    'value': 'Mr J Dorward',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'nameentityofficer',
#    'value': 'Mr A D Frost',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'ukcompanieshouseregisterednumber',
#    'value': '09749826',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'addressline1',
#    'value': '3000a Parkway',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'principallocation-cityortown',
#    'value': 'Whiteley',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'countyregion',
#    'value': 'Hampshire',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'postalcodezip',
#    'value': 'PO15 7FX',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'nameentityaccountants',
#    'value': 'Menzies LLP',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'nameorlocationaccountantsoffice',
#    'value': 'Whiteley',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'propertyplantequipment',
#    'value': 16237.0,
#    'unit': 'iso4217:GBP',
#    'date': '2017-08-31'},
#   {'name': 'propertyplantequipment',
#    'value': 21450.0,
#    'unit': 'iso4217:GBP',
#    'date': '2016-08-31'},
#   {'name': 'fixedassets',
#    'value': 16237.0,
#    'unit': 'iso4217:GBP',
#    'date': '2017-08-31'},
#   {'name': 'fixedassets',
#    'value': 21450.0,
#    'unit': 'iso4217:GBP',
#    'date': '2016-08-31'},
#   {'name': 'debtors',
#    'value': 64746.0,
#    'unit': 'iso4217:GBP',
#    'date': '2017-08-31'},
#   {'name': 'debtors',
#    'value': 24586.0,
#    'unit': 'iso4217:GBP',
#    'date': '2016-08-31'},
#   {'name': 'cashbankonhand',
#    'value': 1636.0,
#    'unit': 'iso4217:GBP',
#    'date': '2017-08-31'},
#   {'name': 'cashbankonhand',
#    'value': 48362.0,
#    'unit': 'iso4217:GBP',
#    'date': '2016-08-31'},
#   {'name': 'currentassets',
#    'value': 66382.0,
#    'unit': 'iso4217:GBP',
#    'date': '2017-08-31'},
#   {'name': 'currentassets',
#    'value': 72948.0,
#    'unit': 'iso4217:GBP',
#    'date': '2016-08-31'},
#   {'name': 'creditors',
#    'value': 49412.0,
#    'unit': 'iso4217:GBP',
#    'date': '2017-08-31'},
#   {'name': 'creditors',
#    'value': 49331.0,
#    'unit': 'iso4217:GBP',
#    'date': '2016-08-31'},
#   {'name': 'netcurrentassetsliabilities',
#    'value': 16970.0,
#    'unit': 'iso4217:GBP',
#    'date': '2017-08-31'},
#   {'name': 'netcurrentassetsliabilities',
#    'value': 23617.0,
#    'unit': 'iso4217:GBP',
#    'date': '2016-08-31'},
#   {'name': 'totalassetslesscurrentliabilities',
#    'value': 33207.0,
#    'unit': 'iso4217:GBP',
#    'date': '2017-08-31'},
#   {'name': 'totalassetslesscurrentliabilities',
#    'value': 45067.0,
#    'unit': 'iso4217:GBP',
#    'date': '2016-08-31'},
#   {'name': 'netassetsliabilities',
#    'value': 33207.0,
#    'unit': 'iso4217:GBP',
#    'date': '2017-08-31'},
#   {'name': 'netassetsliabilities',
#    'value': 45067.0,
#    'unit': 'iso4217:GBP',
#    'date': '2016-08-31'},
#   {'name': 'equity',
#    'value': 100.0,
#    'unit': 'iso4217:GBP',
#    'date': '2017-08-31'},
#   {'name': 'equity',
#    'value': 100.0,
#    'unit': 'iso4217:GBP',
#    'date': '2016-08-31'},
#   {'name': 'equity',
#    'value': 33107.0,
#    'unit': 'iso4217:GBP',
#    'date': '2017-08-31'},
#   {'name': 'equity',
#    'value': 44967.0,
#    'unit': 'iso4217:GBP',
#    'date': '2016-08-31'},
#   {'name': 'equity',
#    'value': 33207.0,
#    'unit': 'iso4217:GBP',
#    'date': '2017-08-31'},
#   {'name': 'equity',
#    'value': 45067.0,
#    'unit': 'iso4217:GBP',
#    'date': '2016-08-31'},
#   {'name': 'statementthatcompanyentitledtoexemptionfromauditundersection477companiesact2006relatingtosmallcompanies',
#    'value': 'The\xa0directors\xa0consider\xa0that the\xa0Company\xa0is entitled to exemption from audit under section 477 of the\xa0Companies Act 2006\xa0and members have not required the\xa0Company\xa0to obtain an audit for the\xa0year\xa0in question in accordance with section 476 of\xa0Companies Act 2006.',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'statementthatdirectorsacknowledgetheirresponsibilitiesundercompaniesact',
#    'value': 'The\xa0directors\xa0acknowledge\xa0their\xa0responsibilities for complying with the requirements of the\xa0Companies Act 2006\xa0with respect to accounting records and the preparation of\xa0financial statements.',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'statementthataccountshavebeenpreparedinaccordancewithprovisionssmallcompaniesregime',
#    'value': 'The\xa0financial statements\xa0have been prepared in accordance with the provisions applicable to companies subject to the\xa0small companies regime and in accordance with the provisions of FRS 102 Section 1A - small entities.',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'nameentityofficer',
#    'value': 'Mr A D Frost',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'directorsigningfinancialstatements',
#    'value': 'Director2',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'dateauthorisationfinancialstatementsforissue',
#    'value': '30 April 2018',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'revenuerecognitionpolicy',
#    'value': '\n\nRevenue\xa0is recognised to the extent that it is probable that the economic benefits will flow to the\xa0Company\xa0and the\xa0revenue\xa0can be reliably measured.\xa0Revenue\xa0is measured as the fair value of the consideration received or receivable, excluding discounts, rebates, value added tax and other sales taxes. The following criteria must also be met before\xa0revenue\xa0is recognised:\n\n\n\n\n\nSale of goods\n\n\n\n\n\nRevenue\xa0from the sale of goods is recognised when all of the following conditions are satisfied:\n\n\n∙the\xa0Company\xa0has transferred the significant risks and rewards of ownership to the buyer;\n\n\n∙the\xa0Company\xa0retains neither continuing managerial involvement to the degree usually associated with ownership nor effective control over the goods sold;\n\n\n∙the amount of\xa0revenue\xa0can be measured reliably;\n\n\n∙it is probable that the\xa0Company\xa0will receive the consideration due under the transaction; and\n\n\n∙the costs incurred or to be incurred in respect of the transaction can be measured reliably.\n\n\n\n\n',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'descriptionmeasurementbasisforpropertyplantequipment',
#    'value': 'Tangible fixed assets under the cost model\xa0are stated at historical cost less accumulated depreciation and any accumulated impairment losses. Historical cost includes expenditure that is directly attributable to bringing the asset to the location and condition necessary for it to be capable of operating in the manner intended by management.',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'descriptiondepreciationmethodforpropertyplantequipment',
#    'value': '25% Reducing Balance',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'tradereceivablespolicy',
#    'value': '\n\nShort term debtors are measured at transaction price, less any impairment. Loans receivable are measured initially at fair value, net of transaction costs, and are measured subsequently at amortised cost using the effective interest method, less any impairment.\n\n\n\n\n',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'cashcashequivalentspolicy',
#    'value': '\n\nCash is represented by cash in hand and deposits with financial institutions repayable without penalty on notice of not more than 24 hours. Cash equivalents are highly liquid investments that mature in no more than three months from the date of acquisition and that are readily convertible to known amounts of cash with insignificant risk of change in value.\n\n\n\n\n',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'financialinstrumentsclassificationpolicy',
#    'value': 'The\xa0Company\xa0only enters into basic financial instrument transactions that result in the recognition of financial assets and liabilities like trade and other debtors and creditors, loans from banks and other third parties, loans to related parties and investments in non-puttable ordinary shares.',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'financialinstrumentsrecognitionmeasurementpolicy',
#    'value': '\n\nFinancial assets and liabilities are offset and the net amount reported in the\xa0Statement of financial position\xa0when there is an enforceable right to set off the recognised amounts and there is an intention to settle on a net basis or to realise the asset and settle the liability simultaneously.\n\n\n\n\n',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'tradepayablespolicy',
#    'value': '\n\nShort term creditors are measured at the transaction price. Other financial liabilities, including bank loans, are measured initially at fair value, net of transaction costs, and are measured subsequently at amortised cost using the effective interest method.\n\n\n\n\n',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'financeincomecostspolicy',
#    'value': '\n\nFinance costs are charged to the\xa0Statement of income and retained earnings\xa0over the term of the debt using the effective interest method so that the amount charged is at a constant rate on the carrying amount. Issue costs are initially recognised as a reduction in the proceeds of the associated capital instrument.\n\n\n\n\n',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'borrowingcostspolicy',
#    'value': '\n\nAll borrowing costs are recognised in the\xa0Statement of income and retained earnings\xa0in the\xa0year\xa0in which they are incurred.\n\n\n\n\n',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'taxpolicy',
#    'value': 'Tax is recognised in the\xa0Statement of income and retained earnings, except that a charge attributable to an item of income and expense recognised as other comprehensive income or to an item recognised directly in equity is also recognised in other comprehensive income or directly in equity respectively.',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'currentincometaxpolicy',
#    'value': 'The current income tax charge is calculated on the basis of tax rates and laws that have been enacted or substantively enacted by the\xa0reporting date\xa0in the countries where the\xa0Company operates and generates income.',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'averagenumberemployeesduringperiod',
#    'value': 2.0,
#    'unit': 'xbrli:pure',
#    'date': '2017-08-31'},
#   {'name': 'averagenumberemployeesduringperiod',
#    'value': 2.0,
#    'unit': 'xbrli:pure',
#    'date': '2016-08-31'},
#   {'name': 'propertyplantequipmentgrosscost',
#    'value': 28600.0,
#    'unit': 'iso4217:GBP',
#    'date': '2016-08-31'},
#   {'name': 'additionsotherthanthroughbusinesscombinationspropertyplantequipment',
#    'value': 200.0,
#    'unit': 'iso4217:GBP',
#    'date': '2017-08-31'},
#   {'name': 'propertyplantequipmentgrosscost',
#    'value': 28800.0,
#    'unit': 'iso4217:GBP',
#    'date': '2017-08-31'},
#   {'name': 'accumulateddepreciationnotincludingimpairmentpropertyplantequipment',
#    'value': 7150.0,
#    'unit': 'iso4217:GBP',
#    'date': '2016-08-31'},
#   {'name': 'increasefromdepreciationchargeforyearpropertyplantequipment',
#    'value': 5413.0,
#    'unit': 'iso4217:GBP',
#    'date': '2017-08-31'},
#   {'name': 'accumulateddepreciationimpairmentpropertyplantequipment',
#    'value': 12563.0,
#    'unit': 'iso4217:GBP',
#    'date': '2017-08-31'},
#   {'name': 'propertyplantequipment',
#    'value': 16237.0,
#    'unit': 'iso4217:GBP',
#    'date': '2017-08-31'},
#   {'name': 'propertyplantequipment',
#    'value': 21450.0,
#    'unit': 'iso4217:GBP',
#    'date': '2016-08-31'},
#   {'name': 'tradedebtorstradereceivables',
#    'value': 18360.0,
#    'unit': 'iso4217:GBP',
#    'date': '2017-08-31'},
#   {'name': 'otherdebtors',
#    'value': 46386.0,
#    'unit': 'iso4217:GBP',
#    'date': '2017-08-31'},
#   {'name': 'otherdebtors',
#    'value': 24586.0,
#    'unit': 'iso4217:GBP',
#    'date': '2016-08-31'},
#   {'name': 'debtors',
#    'value': 64746.0,
#    'unit': 'iso4217:GBP',
#    'date': '2017-08-31'},
#   {'name': 'debtors',
#    'value': 24586.0,
#    'unit': 'iso4217:GBP',
#    'date': '2016-08-31'},
#   {'name': 'bankborrowings',
#    'value': 11000.0,
#    'unit': 'iso4217:GBP',
#    'date': '2017-08-31'},
#   {'name': 'tradecreditorstradepayables',
#    'value': 33874.0,
#    'unit': 'iso4217:GBP',
#    'date': '2017-08-31'},
#   {'name': 'tradecreditorstradepayables',
#    'value': 28011.0,
#    'unit': 'iso4217:GBP',
#    'date': '2016-08-31'},
#   {'name': 'corporationtaxpayable',
#    'value': 3538.0,
#    'unit': 'iso4217:GBP',
#    'date': '2017-08-31'},
#   {'name': 'corporationtaxpayable',
#    'value': 11910.0,
#    'unit': 'iso4217:GBP',
#    'date': '2016-08-31'},
#   {'name': 'othertaxationsocialsecuritypayable',
#    'value': 8410.0,
#    'unit': 'iso4217:GBP',
#    'date': '2016-08-31'},
#   {'name': 'accruedliabilitiesdeferredincome',
#    'value': 1000.0,
#    'unit': 'iso4217:GBP',
#    'date': '2017-08-31'},
#   {'name': 'accruedliabilitiesdeferredincome',
#    'value': 1000.0,
#    'unit': 'iso4217:GBP',
#    'date': '2016-08-31'},
#   {'name': 'creditors',
#    'value': 49412.0,
#    'unit': 'iso4217:GBP',
#    'date': '2017-08-31'},
#   {'name': 'creditors',
#    'value': 49331.0,
#    'unit': 'iso4217:GBP',
#    'date': '2016-08-31'}]}

# %% [markdown]
# # Retrieve elements

# %%
# Loop through the document, retrieving any element with a matching name
for element in doc['elements']:
    if element['name'] == 'netassetsliabilitiesincludingpensionassetliability':
        print(element)
# Out:
# {'name': 'netassetsliabilitiesincludingpensionassetliability', 'value': 88402.0, 'unit': 'iso4217:GBP', 'date': '2016-09-30'}
# {'name': 'netassetsliabilitiesincludingpensionassetliability', 'value': 81151.0, 'unit': 'iso4217:GBP', 'date': '2015-09-30'}

# %%
# Extract the all the data to long-thin table format for use with SQL
# Note, tables from docs should be appendable to one another to create
# tables of all data
xp.flatten_data(doc).head(15)
# Out:
#           date                                               name  \
# 0   2016-09-30                                  companynotdormant
# 1   2016-09-30                             entitycurrentlegalname
# 2   2016-09-30                     companieshouseregisterednumber
# 3   2016-09-30                                   balancesheetdate
# 4   2016-09-30                           profitlossaccountreserve
# 5   2015-09-30                           profitlossaccountreserve
# 6   2016-09-30                                   shareholderfunds
# 7   2015-09-30                                   shareholderfunds
# 8   2016-09-30                               calledupsharecapital
# 9   2015-09-30                               calledupsharecapital
# 10  2016-09-30  netassetsliabilitiesincludingpensionassetliabi...
# 11  2015-09-30  netassetsliabilitiesincludingpensionassetliabi...
# 12  2016-09-30                    provisionsforliabilitiescharges
# 13  2015-09-30                    provisionsforliabilitiescharges
# 14  2016-09-30                  totalassetslesscurrentliabilities
#
#            unit                             value  \
# 0            NA                              true
# 1            NA  S.L.M. (Model) Engineers Limited
# 2            NA                          00958610
# 3            NA                        2016-09-30
# 4   iso4217:GBP                             83402
# 5   iso4217:GBP                             76151
# 6   iso4217:GBP                             88402
# 7   iso4217:GBP                             81151
# 8   iso4217:GBP                              5000
# 9   iso4217:GBP                              5000
# 10  iso4217:GBP                             88402
# 11  iso4217:GBP                             81151
# 12  iso4217:GBP                                 0
# 13  iso4217:GBP                              6575
# 14  iso4217:GBP                             88402
#
#                               doc_name doc_type             doc_upload_date  \
# 0   Prod224_0042_00958610_20160930.xml      xml  2019-02-19 16:32:22.789529
# 1   Prod224_0042_00958610_20160930.xml      xml  2019-02-19 16:32:22.789529
# 2   Prod224_0042_00958610_20160930.xml      xml  2019-02-19 16:32:22.789529
# 3   Prod224_0042_00958610_20160930.xml      xml  2019-02-19 16:32:22.789529
# 4   Prod224_0042_00958610_20160930.xml      xml  2019-02-19 16:32:22.789529
# 5   Prod224_0042_00958610_20160930.xml      xml  2019-02-19 16:32:22.789529
# 6   Prod224_0042_00958610_20160930.xml      xml  2019-02-19 16:32:22.789529
# 7   Prod224_0042_00958610_20160930.xml      xml  2019-02-19 16:32:22.789529
# 8   Prod224_0042_00958610_20160930.xml      xml  2019-02-19 16:32:22.789529
# 9   Prod224_0042_00958610_20160930.xml      xml  2019-02-19 16:32:22.789529
# 10  Prod224_0042_00958610_20160930.xml      xml  2019-02-19 16:32:22.789529
# 11  Prod224_0042_00958610_20160930.xml      xml  2019-02-19 16:32:22.789529
# 12  Prod224_0042_00958610_20160930.xml      xml  2019-02-19 16:32:22.789529
# 13  Prod224_0042_00958610_20160930.xml      xml  2019-02-19 16:32:22.789529
# 14  Prod224_0042_00958610_20160930.xml      xml  2019-02-19 16:32:22.789529
#
#                    arc_name  parsed doc_balancesheetdate  \
# 0   example_data_XBRL_iXBRL    True           2016-09-30
# 1   example_data_XBRL_iXBRL    True           2016-09-30
# 2   example_data_XBRL_iXBRL    True           2016-09-30
# 3   example_data_XBRL_iXBRL    True           2016-09-30
# 4   example_data_XBRL_iXBRL    True           2016-09-30
# 5   example_data_XBRL_iXBRL    True           2016-09-30
# 6   example_data_XBRL_iXBRL    True           2016-09-30
# 7   example_data_XBRL_iXBRL    True           2016-09-30
# 8   example_data_XBRL_iXBRL    True           2016-09-30
# 9   example_data_XBRL_iXBRL    True           2016-09-30
# 10  example_data_XBRL_iXBRL    True           2016-09-30
# 11  example_data_XBRL_iXBRL    True           2016-09-30
# 12  example_data_XBRL_iXBRL    True           2016-09-30
# 13  example_data_XBRL_iXBRL    True           2016-09-30
# 14  example_data_XBRL_iXBRL    True           2016-09-30
#
#    doc_companieshouseregisterednumber doc_standard_type doc_standard_date  \
# 0                            00958610        uk-gaap-ae        2009-06-21
# 1                            00958610        uk-gaap-ae        2009-06-21
# 2                            00958610        uk-gaap-ae        2009-06-21
# 3                            00958610        uk-gaap-ae        2009-06-21
# 4                            00958610        uk-gaap-ae        2009-06-21
# 5                            00958610        uk-gaap-ae        2009-06-21
# 6                            00958610        uk-gaap-ae        2009-06-21
# 7                            00958610        uk-gaap-ae        2009-06-21
# 8                            00958610        uk-gaap-ae        2009-06-21
# 9                            00958610        uk-gaap-ae        2009-06-21
# 10                           00958610        uk-gaap-ae        2009-06-21
# 11                           00958610        uk-gaap-ae        2009-06-21
# 12                           00958610        uk-gaap-ae        2009-06-21
# 13                           00958610        uk-gaap-ae        2009-06-21
# 14                           00958610        uk-gaap-ae        2009-06-21
#
#                                     doc_standard_link
# 0   http://www.companieshouse.gov.uk/ef/xbrl/uk/fr...
# 1   http://www.companieshouse.gov.uk/ef/xbrl/uk/fr...
# 2   http://www.companieshouse.gov.uk/ef/xbrl/uk/fr...
# 3   http://www.companieshouse.gov.uk/ef/xbrl/uk/fr...
# 4   http://www.companieshouse.gov.uk/ef/xbrl/uk/fr...
# 5   http://www.companieshouse.gov.uk/ef/xbrl/uk/fr...
# 6   http://www.companieshouse.gov.uk/ef/xbrl/uk/fr...
# 7   http://www.companieshouse.gov.uk/ef/xbrl/uk/fr...
# 8   http://www.companieshouse.gov.uk/ef/xbrl/uk/fr...
# 9   http://www.companieshouse.gov.uk/ef/xbrl/uk/fr...
# 10  http://www.companieshouse.gov.uk/ef/xbrl/uk/fr...
# 11  http://www.companieshouse.gov.uk/ef/xbrl/uk/fr...
# 12  http://www.companieshouse.gov.uk/ef/xbrl/uk/fr...
# 13  http://www.companieshouse.gov.uk/ef/xbrl/uk/fr...
# 14  http://www.companieshouse.gov.uk/ef/xbrl/uk/fr...

# %%
# Finally, build a table of all variables from all example (digital) documents
# This can take a while

# Empty table awaiting results
results = pd.DataFrame()

# For every file
for file in files:
    
    # Read the file
    doc = xp.process_account(file)
    
    # tabulate the results
    doc_df = xp.flatten_data(doc)
    
    # append to table
    results = results.append(doc_df)

# %%
results.head(15)
# Out:
#                    arc_name        date doc_balancesheetdate  \
# 0   example_data_XBRL_iXBRL  2016-09-30           2016-09-30
# 1   example_data_XBRL_iXBRL  2016-09-30           2016-09-30
# 2   example_data_XBRL_iXBRL  2016-09-30           2016-09-30
# 3   example_data_XBRL_iXBRL  2016-09-30           2016-09-30
# 4   example_data_XBRL_iXBRL  2016-09-30           2016-09-30
# 5   example_data_XBRL_iXBRL  2015-09-30           2016-09-30
# 6   example_data_XBRL_iXBRL  2016-09-30           2016-09-30
# 7   example_data_XBRL_iXBRL  2015-09-30           2016-09-30
# 8   example_data_XBRL_iXBRL  2016-09-30           2016-09-30
# 9   example_data_XBRL_iXBRL  2015-09-30           2016-09-30
# 10  example_data_XBRL_iXBRL  2016-09-30           2016-09-30
# 11  example_data_XBRL_iXBRL  2015-09-30           2016-09-30
# 12  example_data_XBRL_iXBRL  2016-09-30           2016-09-30
# 13  example_data_XBRL_iXBRL  2015-09-30           2016-09-30
# 14  example_data_XBRL_iXBRL  2016-09-30           2016-09-30
#
#    doc_companieshouseregisterednumber                            doc_name  \
# 0                            00958610  Prod224_0042_00958610_20160930.xml
# 1                            00958610  Prod224_0042_00958610_20160930.xml
# 2                            00958610  Prod224_0042_00958610_20160930.xml
# 3                            00958610  Prod224_0042_00958610_20160930.xml
# 4                            00958610  Prod224_0042_00958610_20160930.xml
# 5                            00958610  Prod224_0042_00958610_20160930.xml
# 6                            00958610  Prod224_0042_00958610_20160930.xml
# 7                            00958610  Prod224_0042_00958610_20160930.xml
# 8                            00958610  Prod224_0042_00958610_20160930.xml
# 9                            00958610  Prod224_0042_00958610_20160930.xml
# 10                           00958610  Prod224_0042_00958610_20160930.xml
# 11                           00958610  Prod224_0042_00958610_20160930.xml
# 12                           00958610  Prod224_0042_00958610_20160930.xml
# 13                           00958610  Prod224_0042_00958610_20160930.xml
# 14                           00958610  Prod224_0042_00958610_20160930.xml
#
#    doc_standard_date                                  doc_standard_link  \
# 0         2009-06-21  http://www.companieshouse.gov.uk/ef/xbrl/uk/fr...
# 1         2009-06-21  http://www.companieshouse.gov.uk/ef/xbrl/uk/fr...
# 2         2009-06-21  http://www.companieshouse.gov.uk/ef/xbrl/uk/fr...
# 3         2009-06-21  http://www.companieshouse.gov.uk/ef/xbrl/uk/fr...
# 4         2009-06-21  http://www.companieshouse.gov.uk/ef/xbrl/uk/fr...
# 5         2009-06-21  http://www.companieshouse.gov.uk/ef/xbrl/uk/fr...
# 6         2009-06-21  http://www.companieshouse.gov.uk/ef/xbrl/uk/fr...
# 7         2009-06-21  http://www.companieshouse.gov.uk/ef/xbrl/uk/fr...
# 8         2009-06-21  http://www.companieshouse.gov.uk/ef/xbrl/uk/fr...
# 9         2009-06-21  http://www.companieshouse.gov.uk/ef/xbrl/uk/fr...
# 10        2009-06-21  http://www.companieshouse.gov.uk/ef/xbrl/uk/fr...
# 11        2009-06-21  http://www.companieshouse.gov.uk/ef/xbrl/uk/fr...
# 12        2009-06-21  http://www.companieshouse.gov.uk/ef/xbrl/uk/fr...
# 13        2009-06-21  http://www.companieshouse.gov.uk/ef/xbrl/uk/fr...
# 14        2009-06-21  http://www.companieshouse.gov.uk/ef/xbrl/uk/fr...
#
#    doc_standard_type doc_type             doc_upload_date  \
# 0         uk-gaap-ae      xml  2019-02-19 16:32:40.785174
# 1         uk-gaap-ae      xml  2019-02-19 16:32:40.785174
# 2         uk-gaap-ae      xml  2019-02-19 16:32:40.785174
# 3         uk-gaap-ae      xml  2019-02-19 16:32:40.785174
# 4         uk-gaap-ae      xml  2019-02-19 16:32:40.785174
# 5         uk-gaap-ae      xml  2019-02-19 16:32:40.785174
# 6         uk-gaap-ae      xml  2019-02-19 16:32:40.785174
# 7         uk-gaap-ae      xml  2019-02-19 16:32:40.785174
# 8         uk-gaap-ae      xml  2019-02-19 16:32:40.785174
# 9         uk-gaap-ae      xml  2019-02-19 16:32:40.785174
# 10        uk-gaap-ae      xml  2019-02-19 16:32:40.785174
# 11        uk-gaap-ae      xml  2019-02-19 16:32:40.785174
# 12        uk-gaap-ae      xml  2019-02-19 16:32:40.785174
# 13        uk-gaap-ae      xml  2019-02-19 16:32:40.785174
# 14        uk-gaap-ae      xml  2019-02-19 16:32:40.785174
#
#                                                  name  parsed sign  \
# 0                                   companynotdormant    True  NaN
# 1                              entitycurrentlegalname    True  NaN
# 2                      companieshouseregisterednumber    True  NaN
# 3                                    balancesheetdate    True  NaN
# 4                            profitlossaccountreserve    True  NaN
# 5                            profitlossaccountreserve    True  NaN
# 6                                    shareholderfunds    True  NaN
# 7                                    shareholderfunds    True  NaN
# 8                                calledupsharecapital    True  NaN
# 9                                calledupsharecapital    True  NaN
# 10  netassetsliabilitiesincludingpensionassetliabi...    True  NaN
# 11  netassetsliabilitiesincludingpensionassetliabi...    True  NaN
# 12                    provisionsforliabilitiescharges    True  NaN
# 13                    provisionsforliabilitiescharges    True  NaN
# 14                  totalassetslesscurrentliabilities    True  NaN
#
#            unit                             value
# 0            NA                              true
# 1            NA  S.L.M. (Model) Engineers Limited
# 2            NA                          00958610
# 3            NA                        2016-09-30
# 4   iso4217:GBP                             83402
# 5   iso4217:GBP                             76151
# 6   iso4217:GBP                             88402
# 7   iso4217:GBP                             81151
# 8   iso4217:GBP                              5000
# 9   iso4217:GBP                              5000
# 10  iso4217:GBP                             88402
# 11  iso4217:GBP                             81151
# 12  iso4217:GBP                                 0
# 13  iso4217:GBP                              6575
# 14  iso4217:GBP                             88402

# %% [markdown]
# That's ~380 files extracted to obtain ~ 22,000 variables - on average 60 variables per record.  As you've just seen though, extraction can take a while!  Searching through the documents using BeautifulSoup can take a long time, especially where chasing element links to get information on units.  Hopefully this is the sort of thing that can be optimised in future, or it'll be rendered irrelevant by Moore's Law.

# %%
results.to_csv("example_extracted_XBRL_data.csv", index=False)

# %% [markdown]
# # Get summary variables
#
# These I've implemented to work off the MongoDB/Dict representation of the data that the scraping code returns.  It's assumed that if you wish to work with the "flattened" SQL-compatible data instead you can develop your own queries :)

# %%
index = 3
doc = xp.process_account(files[index])

# This tries to add up every variable it can find in a list of variable names
test = xp.summarise_by_sum(doc, ["fixedassets",
                                 "currentassets",
                                 "intangibleassets",
                                 "tangiblefixedassets",
                                 "intangiblefixedassets",
                                 "investmentsfixedassets",
                                 "cashbankinhand",
                                 "cashbankonhand",
                                 "cashbank",
                                 "cashonhand",
                                 "cashinhand",
                                 "calledupsharecapitalnotpaidnotexpressedascurrentasset",
                                 "otherdebtors"])
test

# %%
# This returns the first variable it finds in a prioritised list
# Here I've gone looking for net assets/liabilities
test = xp.summarise_by_priority(doc, ["netassetsliabilitiesincludingpensionasset",
                                      "netassetsliabilityexcludingpensionasset",
                                      "netassetsliabilities",
                                      "totalassetslesscurrentliabilities",
                                      "netcurrentassetsliabilities"])

test

# %%
# Here I've applied it to shareholder funds/equity
test = xp.summarise_by_priority(doc, ["shareholderfunds",
                                      "equity",
                                      "capitalandreserves"])

test

# %%
# This one just tries to return all named variables
test = xp.summarise_set(doc, ["creditors",
                              "debtors",
                              'accountstypefullorabbreviated',
                              'descriptionprincipalactivities',
                              'accountingstandardsapplied',
                              'entitytradingstatus'])
test

# %% [markdown]
# # Finding consolidated status
#
# It turns out that "consolidated" will be tricky - variables exist for it in xbrl/ixbrl docs but they're missleading.  A lot of companies have such a variable and then set the value to "False".

# %%
allvars = pd.read_csv("all_variables_sources.csv")

allvars.head()
# Out:
#    Unnamed: 0  Element Count  \
# 0          12       258094.0
# 1          14       240395.0
# 2          19       160318.0
# 3          23       139584.0
# 4          24       120765.0
#
#                                         Element Name  Of Which are Numerical  \
# 0                                   shareholderfunds                258094.0
# 1  netassetsliabilitiesincludingpensionassetliabi...                240395.0
# 2                          creditorsduewithinoneyear                160318.0
# 3                   sharecapitalallottedcalleduppaid                139584.0
# 4                                     cashbankinhand                120765.0
#
#          source
# 0  uk-gaap-full
# 1  uk-gaap-full
# 2  uk-gaap-full
# 3  uk-gaap-full
# 4  uk-gaap-full

# %%
consolidation_vars = allvars[allvars['Element Name'].str.contains("consoli")]
consolidation_vars.sort_values("Element Count", ascending=False)

# %%
consolidation_vars = allvars[allvars['Element Name'].str.contains("parent")]
consolidation_vars.sort_values("Element Count", ascending=False)

# %%
consolidation_vars = allvars[allvars['Element Name'].str.contains("accou")]
consolidation_vars.sort_values("Element Count", ascending=False)

# %%
consolidation_vars = allvars[allvars['Element Name'].str.contains("activit")]
consolidation_vars.sort_values("Element Count", ascending=False)

# %%
# manual filter to relevant vars from remaining
for each in consolidation_vars['Element Name']:
    print(each)

# %%
# Built a truth table; for each variable what value should it have to mark a company as consolidated?
consolidation_var_table = {
    "includedinconsolidationsubsidiary":True,
    "investmententityrequiredtoapplyexceptionfromconsolidationtruefalse":True,
    "subsidiaryunconsolidatedtruefalse":False,
    "descriptionreasonwhyentityhasnotpreparedconsolidatedfinancialstatements":"exist",
    "consolidationpolicy":"exist",
    }

# %%
import pymongo

cl = pymongo.MongoClient()
db = cl['CH_records']
col = db['digital_record_scrapes']

# %%
col.find().count()
# Out:
# /home/martin/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   """Entry point for launching an IPython kernel.
# 3015767

# %%
docs = col.find().limit(300000)

# %%
results = pd.DataFrame()

for doc in docs:
    
    for each in doc['elements']:
    
        if each['name'] in consolidation_var_table.keys():
        
            res = {"record":doc['doc_companieshouseregisterednumber'],
                   "variable":each['name'],
                   "value":each['value'],
                   "truthval":consolidation_var_table[each['name']]}
        
            results = results.append(res, ignore_index=True)

# %%
results.head()

# %%
results['variable'].unique()

# %%
results[['variable', 'value', 'record']].groupby(['variable', 'value']).agg('count').to_csv("example_consolidation_variables.csv")

# %%
results[['variable', 'value', 'record']].groupby(['variable', 'value']).agg('count')

# %% [markdown]
# # Extracting principal activities

# %%
docs = col.find(no_cursor_timeout=True)

descriptions = pd.DataFrame()

counter = 0
for doc in docs:
    
    try:
        for each in doc['elements']:
    
            if each['name'] == "descriptionprincipalactivities":
        
                res = {"companieshouseregisterednumber":doc['doc_companieshouseregisterednumber'],
                       "balancesheetdate":doc['doc_balancesheetdate'],
                       "descriptionprincipalactivities":each['value']}
        
                descriptions = descriptions.append(res, ignore_index=True)
                
                counter = counter + 1
                
                if counter % 10000 == 0:
                    
                    if counter > 10000:
                        with open("companieshousedescriptions.csv", "a") as f:
                            descriptions.to_csv(f, header=False)
                            print("appended data at ", counter)

                    else:
                        with open("companieshousedescriptions.csv", "w") as f:
                            descriptions.to_csv(f)
                            print("created_data at ", counter)
                    
                    descriptions = pd.DataFrame()
                    
                break
    
    except:
        pass

with open("companieshousedescriptions.csv", "a") as f:
    descriptions.to_csv(f, header=False)
    print("appended data at ", counter)

# %%
descriptions = pd.read_csv("companieshousedescriptions.csv")

descriptions.head()
# Out:
#    Unnamed: 0 balancesheetdate companieshouseregisterednumber  \
# 0           0       2017-06-30                       08028272
# 1           1       2017-06-30                       04761288
# 2           2       2017-08-31                       10314494
# 3           3       2016-12-31                       03127240
# 4           4       2017-06-30                       05735108
#
#                       descriptionprincipalactivities
# 0  The principal activity of the company is Motor...
# 1               No description of principal activity
# 2               No description of principal activity
# 3               No description of principal activity
# 4               No description of principal activity

# %%
len(descriptions['descriptionprincipalactivities'].unique())
# Out:
# 121785

# %%
descriptions[['companieshouseregisterednumber', 'descriptionprincipalactivities']].\
    groupby('descriptionprincipalactivities').agg('count').\
    sort_values('companieshouseregisterednumber', ascending=False).head(20)
# Out:
#                                                     companieshouseregisterednumber
# descriptionprincipalactivities
# No description of principal activity                                        527830
# No description of principal activities is discl...                            5093
# No principle activity is included                                             2453
# The company is dormant and has not traded durin...                            2087
# The principal activity of the company during th...                            1730
# The principal activity of the company in the ye...                            1281
# The principal activity of the company is Inform...                             937
# IT contracting                                                                 862
# The company is dormant and has not traded durin...                             860
# The principal activity of the company in the pe...                             845
# The Company is dormant and has not traded durin...                             842
# This company sells stuff to other companies                                    711
# IT consultancy                                                                 674
# The principal activity of the company is dormant                               525
# IT consulting                                                                  518
# The principal activity of the company is transp...                             488
# The principal activity of the company is Consul...                             449
# The principal activity of the company is IT Con...                             440
# The principal activity of the company is Dormant                               437
# The principal activity of the company is the pr...                             431
