# %% [markdown]
# # Extracting Data from Companies House Electronic Records
#
# Companies house receives 75% of its records in XBRL or iXBRL format, a glorified tagged xml document that should allow for easy automated extraction of statistics.
#
# The software in this repo was developed after reading of this (American) example:
# https://www.codeproject.com/Articles/1227765/Parsing-XBRL-with-Python
#
# The functions for doing so are hosted in the module xbrl_parser.py
#
# Both xbrl_parser.py and this script have a number of python package dependencies so expect to have to install some things.

# %% [markdown]
# ## Returned dict schema for html/xml sourced data
#
# A practical note:  Apart from explicitly elevated metadata, all extracted values are stored in a list of "elements" within the returned dict.  Each element is itself a dict, containing the name and value of the discovered data along with fields unit and date for metadata.

# %% [markdown]
# # Setup (import modules, set up a helper function for getting filepaths)

# %%
import xbrl_parser as xp
import os
import numpy as np
import pandas as pd
import importlib

def get_filepaths(directory):

    """ Helper function - 
    Get all of the filenames in a directory that
    end in htm* or xml.
    Under the assumption that all files within
    the folder are financial records. """

    files = [directory + "/" + filename
                for filename in os.listdir(directory)
                    if (("htm" in filename.lower()) or ("xml" in filename.lower())) ]
    return(files)

# %% [markdown]
# # Extracting data from documents
#
# We'll import the module, and process some files

# %%
# Get all the filenames from the example folder
files = get_filepaths("./example_data_XBRL_iXBRL")

# There's 379 examples currently
files[0:7]
# Out:
# ['./example_data_XBRL_iXBRL/Prod224_0042_00958610_20160930.xml',
#  './example_data_XBRL_iXBRL/Prod223_2125_09749826_20170831.html',
#  './example_data_XBRL_iXBRL/Prod223_2125_09170142_20170831.html',
#  './example_data_XBRL_iXBRL/Prod224_0042_03237381_20160831.xml',
#  './example_data_XBRL_iXBRL/Prod223_2125_09900460_20161231.html',
#  './example_data_XBRL_iXBRL/Prod223_2125_09652609_20180331.html',
#  './example_data_XBRL_iXBRL/Prod223_2125_09722743_20170831.html']

# %%
# try getting the first file (an XML, or XBRL, file)
importlib.reload(xp)
doc = xp.process_account(files[2])

# View the content
doc
# Out:
# ./example_data_XBRL_iXBRL/Prod223_2125_09170142_20170831.html
# {'doc_name': 'Prod223_2125_09170142_20170831.html',
#  'doc_type': 'html',
#  'doc_upload_date': '2018-10-25 15:55:30.730675',
#  'arc_name': 'example_data_XBRL_iXBRL',
#  'parsed': True,
#  'doc_balancesheetdate': '2017-08-31',
#  'doc_companieshouseregisterednumber': '09170142',
#  'doc_standard_type': 'uk-gaap-full',
#  'doc_standard_date': '2009-09-01',
#  'doc_standard_link': 'http://www.xbrl.org/uk/gaap/core/2009-09-01/uk-gaap-full-2009-09-01.xsd',
#  'elements': [{'name': 'ukcompanieshouseregisterednumber',
#    'value': '09170142',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'entitycurrentlegalorregisteredname',
#    'value': 'O THONGTHAI LIMITED',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'balancesheetdate',
#    'value': '2017-08-31',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'namedirectorsigningaccounts',
#    'value': '',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'entitydormant',
#    'value': 'true',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'startdateforperiodcoveredbyreport',
#    'value': '2016-09-01',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'enddateforperiodcoveredbyreport',
#    'value': '2017-08-31',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'entitytrading',
#    'value': 'false',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'companyhasactedasanagentduringperiod',
#    'value': 'false',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'calledupsharecapitalnotpaidnotexpressedascurrentasset',
#    'value': 1.0,
#    'unit': 'GBP',
#    'date': '2017-08-31'},
#   {'name': 'calledupsharecapitalnotpaidnotexpressedascurrentasset',
#    'value': 1.0,
#    'unit': 'GBP',
#    'date': '2016-08-31'},
#   {'name': 'netassetsliabilitiesincludingpensionassetliability',
#    'value': 1.0,
#    'unit': 'GBP',
#    'date': '2017-08-31'},
#   {'name': 'netassetsliabilitiesincludingpensionassetliability',
#    'value': 1.0,
#    'unit': 'GBP',
#    'date': '2016-08-31'},
#   {'name': 'numbersharesallotted',
#    'value': 1.0,
#    'unit': 'other_\nshares\n',
#    'date': '2017-08-31'},
#   {'name': 'descriptionsharetype',
#    'value': 'Ordinary',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'parvalueshare', 'value': 1.0, 'unit': 'GBP', 'date': '2017-08-31'},
#   {'name': 'sharecapitalallottedcalleduppaid',
#    'value': 1.0,
#    'unit': 'GBP',
#    'date': '2017-08-31'},
#   {'name': 'sharecapitalallottedcalleduppaid',
#    'value': 1.0,
#    'unit': 'GBP',
#    'date': '2016-08-31'},
#   {'name': 'shareholderfunds',
#    'value': 1.0,
#    'unit': 'GBP',
#    'date': '2017-08-31'},
#   {'name': 'shareholderfunds',
#    'value': 1.0,
#    'unit': 'GBP',
#    'date': '2016-08-31'},
#   {'name': 'companyentitledtoexemptionundersection480companiesact2006relatingtodormantcompanies',
#    'value': 'For the year ending 31 August 2017 the company was entitled to exemption under section 480 of the Companies Act 2006 relating to dormant companies.',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'membershavenotrequiredcompanytoobtainanaudit',
#    'value': 'The members have not required the company to obtain an audit in accordance with section 476 of the Companies Act 2006.',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'directorsacknowledgetheirresponsibilitiesundercompaniesact',
#    'value': 'The directors acknowledge their responsibilities for complying with the requirements of the Act with respect to accounting records and the preparation of accounts.',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'accountsareinaccordancewithspecialprovisionscompaniesactrelatingtosmallcompanies',
#    'value': 'These accounts have been prepared in accordance with the provisions applicable to companies subject to the small companies regime.',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'dateapprovalaccounts',
#    'value': '3 May 2018',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'nameentityofficer',
#    'value': 'C Thongthai',
#    'unit': 'NA',
#    'date': '2017-08-31'}]}

# %%
# try getting the second file (an HTML, or iXBRL, file)
doc2 = xp.process_account(files[1])

# View the content
doc2
# Out:
# ./example_data_XBRL_iXBRL/Prod223_2125_09749826_20170831.html
# {'doc_name': 'Prod223_2125_09749826_20170831.html',
#  'doc_type': 'html',
#  'doc_upload_date': '2018-10-24 14:15:06.082682',
#  'arc_name': 'example_data_XBRL_iXBRL',
#  'parsed': True,
#  'doc_balancesheetdate': '2017-08-31',
#  'doc_companieshouseregisterednumber': '09749826',
#  'doc_standard_type': 'FRS-102',
#  'doc_standard_date': '2014-09-01',
#  'doc_standard_link': 'https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS-102-2014-09-01.xsd',
#  'elements': [{'name': 'nameproductionsoftware',
#    'value': 'Caseware UK (AP4) 2016.0.181',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'versionproductionsoftware',
#    'value': ' 2016.0.181',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'enddateforperiodcoveredbyreport',
#    'value': '2017-08-31',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'balancesheetdate',
#    'value': '2017-08-31',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'accountstypefullorabbreviated',
#    'value': 'FullAccounts',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'accountingstandardsapplied',
#    'value': 'FRS102',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'entitytradingstatus',
#    'value': '',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'descriptionprincipalactivities',
#    'value': 'No description of principal activity',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'accountsstatusauditedorunaudited',
#    'value': 'AuditExempt-NoAccountantsReport',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'entitydormanttruefalse',
#    'value': 'false',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'startdateforperiodcoveredbyreport',
#    'value': '2016-09-01',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'entityhastakenexemptionundercompaniesactinnotpublishingitsownprofitlossaccounttruefalse',
#    'value': 'true',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'entityhasclaimedexemptionfrompresentingcashflowstatementnotesinlinewithfrs1021.12btruefalse',
#    'value': 'true',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'statementthatmembershavenotrequiredcompanytoobtainanaudit',
#    'value': 'The members have not required the company to obtain an audit in accordance with section 476 of the Companies Act 2006.',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'legalformentity',
#    'value': 'PrivateLimitedCompanyLtd',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'ukcompanieshouseregisterednumber',
#    'value': '09749826',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'entitycurrentlegalorregisteredname',
#    'value': 'J T PLANT SALES LIMITED',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'nameentityofficer',
#    'value': 'Mr J Dorward',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'nameentityofficer',
#    'value': 'Mr A D Frost',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'ukcompanieshouseregisterednumber',
#    'value': '09749826',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'addressline1',
#    'value': '3000a Parkway',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'principallocation-cityortown',
#    'value': 'Whiteley',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'countyregion',
#    'value': 'Hampshire',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'postalcodezip',
#    'value': 'PO15 7FX',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'nameentityaccountants',
#    'value': 'Menzies LLP',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'nameorlocationaccountantsoffice',
#    'value': 'Whiteley',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'propertyplantequipment',
#    'value': 16237.0,
#    'unit': 'GBP',
#    'date': '2017-08-31'},
#   {'name': 'propertyplantequipment',
#    'value': 21450.0,
#    'unit': 'GBP',
#    'date': '2016-08-31'},
#   {'name': 'fixedassets',
#    'value': 16237.0,
#    'unit': 'GBP',
#    'date': '2017-08-31'},
#   {'name': 'fixedassets',
#    'value': 21450.0,
#    'unit': 'GBP',
#    'date': '2016-08-31'},
#   {'name': 'debtors', 'value': 64746.0, 'unit': 'GBP', 'date': '2017-08-31'},
#   {'name': 'debtors', 'value': 24586.0, 'unit': 'GBP', 'date': '2016-08-31'},
#   {'name': 'cashbankonhand',
#    'value': 1636.0,
#    'unit': 'GBP',
#    'date': '2017-08-31'},
#   {'name': 'cashbankonhand',
#    'value': 48362.0,
#    'unit': 'GBP',
#    'date': '2016-08-31'},
#   {'name': 'currentassets',
#    'value': 66382.0,
#    'unit': 'GBP',
#    'date': '2017-08-31'},
#   {'name': 'currentassets',
#    'value': 72948.0,
#    'unit': 'GBP',
#    'date': '2016-08-31'},
#   {'name': 'creditors', 'value': 49412.0, 'unit': 'GBP', 'date': '2017-08-31'},
#   {'name': 'creditors', 'value': 49331.0, 'unit': 'GBP', 'date': '2016-08-31'},
#   {'name': 'netcurrentassetsliabilities',
#    'value': 16970.0,
#    'unit': 'GBP',
#    'date': '2017-08-31'},
#   {'name': 'netcurrentassetsliabilities',
#    'value': 23617.0,
#    'unit': 'GBP',
#    'date': '2016-08-31'},
#   {'name': 'totalassetslesscurrentliabilities',
#    'value': 33207.0,
#    'unit': 'GBP',
#    'date': '2017-08-31'},
#   {'name': 'totalassetslesscurrentliabilities',
#    'value': 45067.0,
#    'unit': 'GBP',
#    'date': '2016-08-31'},
#   {'name': 'netassetsliabilities',
#    'value': 33207.0,
#    'unit': 'GBP',
#    'date': '2017-08-31'},
#   {'name': 'netassetsliabilities',
#    'value': 45067.0,
#    'unit': 'GBP',
#    'date': '2016-08-31'},
#   {'name': 'equity', 'value': 100.0, 'unit': 'GBP', 'date': '2017-08-31'},
#   {'name': 'equity', 'value': 100.0, 'unit': 'GBP', 'date': '2016-08-31'},
#   {'name': 'equity', 'value': 33107.0, 'unit': 'GBP', 'date': '2017-08-31'},
#   {'name': 'equity', 'value': 44967.0, 'unit': 'GBP', 'date': '2016-08-31'},
#   {'name': 'equity', 'value': 33207.0, 'unit': 'GBP', 'date': '2017-08-31'},
#   {'name': 'equity', 'value': 45067.0, 'unit': 'GBP', 'date': '2016-08-31'},
#   {'name': 'statementthatcompanyentitledtoexemptionfromauditundersection477companiesact2006relatingtosmallcompanies',
#    'value': 'The\xa0directors\xa0consider\xa0that the\xa0Company\xa0is entitled to exemption from audit under section 477 of the\xa0Companies Act 2006\xa0and members have not required the\xa0Company\xa0to obtain an audit for the\xa0year\xa0in question in accordance with section 476 of\xa0Companies Act 2006.',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'statementthatdirectorsacknowledgetheirresponsibilitiesundercompaniesact',
#    'value': 'The\xa0directors\xa0acknowledge\xa0their\xa0responsibilities for complying with the requirements of the\xa0Companies Act 2006\xa0with respect to accounting records and the preparation of\xa0financial statements.',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'statementthataccountshavebeenpreparedinaccordancewithprovisionssmallcompaniesregime',
#    'value': 'The\xa0financial statements\xa0have been prepared in accordance with the provisions applicable to companies subject to the\xa0small companies regime and in accordance with the provisions of FRS 102 Section 1A - small entities.',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'nameentityofficer',
#    'value': 'Mr A D Frost',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'directorsigningfinancialstatements',
#    'value': 'Director2',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'dateauthorisationfinancialstatementsforissue',
#    'value': '30 April 2018',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'revenuerecognitionpolicy',
#    'value': '\n\nRevenue\xa0is recognised to the extent that it is probable that the economic benefits will flow to the\xa0Company\xa0and the\xa0revenue\xa0can be reliably measured.\xa0Revenue\xa0is measured as the fair value of the consideration received or receivable, excluding discounts, rebates, value added tax and other sales taxes. The following criteria must also be met before\xa0revenue\xa0is recognised:\n\n\n\n\n\nSale of goods\n\n\n\n\n\nRevenue\xa0from the sale of goods is recognised when all of the following conditions are satisfied:\n\n\n∙the\xa0Company\xa0has transferred the significant risks and rewards of ownership to the buyer;\n\n\n∙the\xa0Company\xa0retains neither continuing managerial involvement to the degree usually associated with ownership nor effective control over the goods sold;\n\n\n∙the amount of\xa0revenue\xa0can be measured reliably;\n\n\n∙it is probable that the\xa0Company\xa0will receive the consideration due under the transaction; and\n\n\n∙the costs incurred or to be incurred in respect of the transaction can be measured reliably.\n\n\n\n\n',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'descriptionmeasurementbasisforpropertyplantequipment',
#    'value': 'Tangible fixed assets under the cost model\xa0are stated at historical cost less accumulated depreciation and any accumulated impairment losses. Historical cost includes expenditure that is directly attributable to bringing the asset to the location and condition necessary for it to be capable of operating in the manner intended by management.',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'descriptiondepreciationmethodforpropertyplantequipment',
#    'value': '25% Reducing Balance',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'tradereceivablespolicy',
#    'value': '\n\nShort term debtors are measured at transaction price, less any impairment. Loans receivable are measured initially at fair value, net of transaction costs, and are measured subsequently at amortised cost using the effective interest method, less any impairment.\n\n\n\n\n',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'cashcashequivalentspolicy',
#    'value': '\n\nCash is represented by cash in hand and deposits with financial institutions repayable without penalty on notice of not more than 24 hours. Cash equivalents are highly liquid investments that mature in no more than three months from the date of acquisition and that are readily convertible to known amounts of cash with insignificant risk of change in value.\n\n\n\n\n',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'financialinstrumentsclassificationpolicy',
#    'value': 'The\xa0Company\xa0only enters into basic financial instrument transactions that result in the recognition of financial assets and liabilities like trade and other debtors and creditors, loans from banks and other third parties, loans to related parties and investments in non-puttable ordinary shares.',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'financialinstrumentsrecognitionmeasurementpolicy',
#    'value': '\n\nFinancial assets and liabilities are offset and the net amount reported in the\xa0Statement of financial position\xa0when there is an enforceable right to set off the recognised amounts and there is an intention to settle on a net basis or to realise the asset and settle the liability simultaneously.\n\n\n\n\n',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'tradepayablespolicy',
#    'value': '\n\nShort term creditors are measured at the transaction price. Other financial liabilities, including bank loans, are measured initially at fair value, net of transaction costs, and are measured subsequently at amortised cost using the effective interest method.\n\n\n\n\n',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'financeincomecostspolicy',
#    'value': '\n\nFinance costs are charged to the\xa0Statement of income and retained earnings\xa0over the term of the debt using the effective interest method so that the amount charged is at a constant rate on the carrying amount. Issue costs are initially recognised as a reduction in the proceeds of the associated capital instrument.\n\n\n\n\n',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'borrowingcostspolicy',
#    'value': '\n\nAll borrowing costs are recognised in the\xa0Statement of income and retained earnings\xa0in the\xa0year\xa0in which they are incurred.\n\n\n\n\n',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'taxpolicy',
#    'value': 'Tax is recognised in the\xa0Statement of income and retained earnings, except that a charge attributable to an item of income and expense recognised as other comprehensive income or to an item recognised directly in equity is also recognised in other comprehensive income or directly in equity respectively.',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'currentincometaxpolicy',
#    'value': 'The current income tax charge is calculated on the basis of tax rates and laws that have been enacted or substantively enacted by the\xa0reporting date\xa0in the countries where the\xa0Company operates and generates income.',
#    'unit': 'NA',
#    'date': '2017-08-31'},
#   {'name': 'averagenumberemployeesduringperiod',
#    'value': 2.0,
#    'unit': 'PURE',
#    'date': '2017-08-31'},
#   {'name': 'averagenumberemployeesduringperiod',
#    'value': 2.0,
#    'unit': 'PURE',
#    'date': '2016-08-31'},
#   {'name': 'propertyplantequipmentgrosscost',
#    'value': 28600.0,
#    'unit': 'GBP',
#    'date': '2016-08-31'},
#   {'name': 'additionsotherthanthroughbusinesscombinationspropertyplantequipment',
#    'value': 200.0,
#    'unit': 'GBP',
#    'date': '2017-08-31'},
#   {'name': 'propertyplantequipmentgrosscost',
#    'value': 28800.0,
#    'unit': 'GBP',
#    'date': '2017-08-31'},
#   {'name': 'accumulateddepreciationnotincludingimpairmentpropertyplantequipment',
#    'value': 7150.0,
#    'unit': 'GBP',
#    'date': '2016-08-31'},
#   {'name': 'increasefromdepreciationchargeforyearpropertyplantequipment',
#    'value': 5413.0,
#    'unit': 'GBP',
#    'date': '2017-08-31'},
#   {'name': 'accumulateddepreciationimpairmentpropertyplantequipment',
#    'value': 12563.0,
#    'unit': 'GBP',
#    'date': '2017-08-31'},
#   {'name': 'propertyplantequipment',
#    'value': 16237.0,
#    'unit': 'GBP',
#    'date': '2017-08-31'},
#   {'name': 'propertyplantequipment',
#    'value': 21450.0,
#    'unit': 'GBP',
#    'date': '2016-08-31'},
#   {'name': 'tradedebtorstradereceivables',
#    'value': 18360.0,
#    'unit': 'GBP',
#    'date': '2017-08-31'},
#   {'name': 'otherdebtors',
#    'value': 46386.0,
#    'unit': 'GBP',
#    'date': '2017-08-31'},
#   {'name': 'otherdebtors',
#    'value': 24586.0,
#    'unit': 'GBP',
#    'date': '2016-08-31'},
#   {'name': 'debtors', 'value': 64746.0, 'unit': 'GBP', 'date': '2017-08-31'},
#   {'name': 'debtors', 'value': 24586.0, 'unit': 'GBP', 'date': '2016-08-31'},
#   {'name': 'bankborrowings',
#    'value': 11000.0,
#    'unit': 'GBP',
#    'date': '2017-08-31'},
#   {'name': 'tradecreditorstradepayables',
#    'value': 33874.0,
#    'unit': 'GBP',
#    'date': '2017-08-31'},
#   {'name': 'tradecreditorstradepayables',
#    'value': 28011.0,
#    'unit': 'GBP',
#    'date': '2016-08-31'},
#   {'name': 'corporationtaxpayable',
#    'value': 3538.0,
#    'unit': 'GBP',
#    'date': '2017-08-31'},
#   {'name': 'corporationtaxpayable',
#    'value': 11910.0,
#    'unit': 'GBP',
#    'date': '2016-08-31'},
#   {'name': 'othertaxationsocialsecuritypayable',
#    'value': 8410.0,
#    'unit': 'GBP',
#    'date': '2016-08-31'},
#   {'name': 'accruedliabilitiesdeferredincome',
#    'value': 1000.0,
#    'unit': 'GBP',
#    'date': '2017-08-31'},
#   {'name': 'accruedliabilitiesdeferredincome',
#    'value': 1000.0,
#    'unit': 'GBP',
#    'date': '2016-08-31'},
#   {'name': 'creditors', 'value': 49412.0, 'unit': 'GBP', 'date': '2017-08-31'},
#   {'name': 'creditors',
#    'value': 49331.0,
#    'unit': 'GBP',
#    'date': '2016-08-31'}]}

# %% [markdown]
# # Retrieve elements

# %%
# Loop through the document, retrieving any element with a matching name
for element in doc['elements']:
    if element['name'] == 'netassetsliabilitiesincludingpensionassetliability':
        print(element)
# Out:
# {'name': 'netassetsliabilitiesincludingpensionassetliability', 'value': 88402.0, 'unit': 'GBP', 'date': '2016-09-30'}
# {'name': 'netassetsliabilitiesincludingpensionassetliability', 'value': 81151.0, 'unit': 'GBP', 'date': '2015-09-30'}

# %%
# Convert all of a document's elements to a pandas dataframe format for ease of searching
df = pd.DataFrame(doc['elements'])
df['company'] = doc['doc_companieshouseregisterednumber']
# Note, all fields are currently string (character) format after extraction
df
# Out:
#            date                                               name  \
# 0    2016-09-30                                  companynotdormant
# 1    2016-09-30                             entitycurrentlegalname
# 2    2016-09-30                     companieshouseregisterednumber
# 3    2016-09-30                                   balancesheetdate
# 4    2016-09-30                           profitlossaccountreserve
# 5    2015-09-30                           profitlossaccountreserve
# 6    2016-09-30                                   shareholderfunds
# 7    2015-09-30                                   shareholderfunds
# 8    2016-09-30                               calledupsharecapital
# 9    2015-09-30                               calledupsharecapital
# 10   2016-09-30  netassetsliabilitiesincludingpensionassetliabi...
# 11   2015-09-30  netassetsliabilitiesincludingpensionassetliabi...
# 12   2016-09-30                    provisionsforliabilitiescharges
# 13   2015-09-30                    provisionsforliabilitiescharges
# 14   2016-09-30                  totalassetslesscurrentliabilities
# 15   2015-09-30                  totalassetslesscurrentliabilities
# 16   2016-09-30                        netcurrentassetsliabilities
# 17   2015-09-30                        netcurrentassetsliabilities
# 18   2016-09-30   creditorsduewithinoneyeartotalcurrentliabilities
# 19   2015-09-30   creditorsduewithinoneyeartotalcurrentliabilities
# 20   2016-09-30                                      currentassets
# 21   2015-09-30                                      currentassets
# 22   2016-09-30                                            debtors
# 23   2015-09-30                                            debtors
# 24   2016-09-30                                    stocksinventory
# 25   2015-09-30                                    stocksinventory
# 26   2016-09-30                                     cashbankinhand
# 27   2015-09-30                                     cashbankinhand
# 28   2016-09-30                                        fixedassets
# 29   2015-09-30                                        fixedassets
# ..          ...                                                ...
# 72   2016-09-30               creditorsdueafteroneyearfreetextnote
# 73   2016-09-30                                  typeordinaryshare
# 74   2016-09-30                     numberordinarysharesauthorised
# 75   2016-09-30                              parvalueordinaryshare
# 76   2016-09-30                      valueordinarysharesauthorised
# 77   2015-09-30                      valueordinarysharesauthorised
# 78   2016-09-30                                  typeordinaryshare
# 79   2016-09-30                     numberordinarysharesauthorised
# 80   2016-09-30                              parvalueordinaryshare
# 81   2016-09-30                      valueordinarysharesauthorised
# 82   2015-09-30                      valueordinarysharesauthorised
# 83   2016-09-30                                  typeordinaryshare
# 84   2016-09-30                              parvalueordinaryshare
# 85   2016-09-30                        valueordinarysharesallotted
# 86   2015-09-30                        valueordinarysharesallotted
# 87   2016-09-30                       numberordinarysharesallotted
# 88   2016-09-30                                  typeordinaryshare
# 89   2016-09-30                              parvalueordinaryshare
# 90   2016-09-30                        valueordinarysharesallotted
# 91   2015-09-30                        valueordinarysharesallotted
# 92   2016-09-30                       numberordinarysharesallotted
# 93   2016-09-30                           sharecapitalfreetextnote
# 94   2016-09-30                                       dateapproval
# 95   2016-09-30                              nameapprovingdirector
# 96   2016-09-30  companyentitledtoexemptionundersection477compa...
# 97   2016-09-30       membershavenotrequiredcompanytoobtainanaudit
# 98   2016-09-30  directorsacknowledgetheirresponsibilitiesunder...
# 99   2016-09-30  accountsareinaccordancewithspecialprovisionsco...
# 100  2016-09-30               companieshousedocumentauthentication
# 101  2016-09-30                               dateaccountsreceived
#
#                    unit                             value   company
# 0                    NA                              true  00958610
# 1                    NA  S.L.M. (Model) Engineers Limited  00958610
# 2                    NA                          00958610  00958610
# 3                    NA                        2016-09-30  00958610
# 4                   GBP                             83402  00958610
# 5                   GBP                             76151  00958610
# 6                   GBP                             88402  00958610
# 7                   GBP                             81151  00958610
# 8                   GBP                              5000  00958610
# 9                   GBP                              5000  00958610
# 10                  GBP                             88402  00958610
# 11                  GBP                             81151  00958610
# 12                  GBP                                 0  00958610
# 13                  GBP                              6575  00958610
# 14                  GBP                             88402  00958610
# 15                  GBP                             87726  00958610
# 16                  GBP                            -17387  00958610
# 17                  GBP                            -21381  00958610
# 18                  GBP                            257865  00958610
# 19                  GBP                            270286  00958610
# 20                  GBP                            240478  00958610
# 21                  GBP                            248905  00958610
# 22                  GBP                            181072  00958610
# 23                  GBP                            184636  00958610
# 24                  GBP                              6678  00958610
# 25                  GBP                              7774  00958610
# 26                  GBP                             52728  00958610
# 27                  GBP                             56495  00958610
# 28                  GBP                            105789  00958610
# 29                  GBP                            109107  00958610
# ..                  ...                               ...       ...
# 72                   NA                                    00958610
# 73                   NA                        A ordinary  00958610
# 74   other_xbrli:shares                             10000  00958610
# 75                  GBP                                 1  00958610
# 76                  GBP                             10000  00958610
# 77                  GBP                             10000  00958610
# 78                   NA                        B ordinary  00958610
# 79   other_xbrli:shares                             10000  00958610
# 80                  GBP                                 1  00958610
# 81                  GBP                             10000  00958610
# 82                  GBP                             10000  00958610
# 83                   NA                        A ordinary  00958610
# 84                  GBP                                 1  00958610
# 85                  GBP                              4900  00958610
# 86                  GBP                              4900  00958610
# 87   other_xbrli:shares                              4900  00958610
# 88                   NA                        B ordinary  00958610
# 89                  GBP                                 1  00958610
# 90                  GBP                               100  00958610
# 91                  GBP                               100  00958610
# 92   other_xbrli:shares                               100  00958610
# 93                   NA                                    00958610
# 94                   NA                        2017-05-23  00958610
# 95                   NA                      Mr M Lewicki  00958610
# 96                   NA                              true  00958610
# 97                   NA                              true  00958610
# 98                   NA                              true  00958610
# 99                   NA                              true  00958610
# 100                  NA                                    00958610
# 101                  NA                        2017-05-24  00958610
#
# [102 rows x 5 columns]
